# %%
import pickle
fr2 = open('dataFilepred_docs.txt','rb')
pred_docs = pickle.load(fr2)
pred_docs
# Out:
# {'16362077': <data_utils.data_utils.Document at 0x1a1887c4198>,
#  '12585968': <data_utils.data_utils.Document at 0x1a1a08146a0>,
#  '17201918': <data_utils.data_utils.Document at 0x1a1a0950c50>,
#  '15850489': <data_utils.data_utils.Document at 0x1a1a0b224a8>,
#  '17608565': <data_utils.data_utils.Document at 0x1a1a0c15588>,
#  '15615595': <data_utils.data_utils.Document at 0x1a1a0ea6ba8>,
#  '15018652': <data_utils.data_utils.Document at 0x1a1a0f97438>,
#  '16221973': <data_utils.data_utils.Document at 0x1a1a1024f60>,
#  '16110338': <data_utils.data_utils.Document at 0x1a1a1314240>,
#  '11597317': <data_utils.data_utils.Document at 0x1a1a14daa58>,
#  '17002498': <data_utils.data_utils.Document at 0x1a1a1555ac8>,
#  '15760270': <data_utils.data_utils.Document at 0x1a1a1777710>,
#  '12079497': <data_utils.data_utils.Document at 0x1a1a1a6f588>,
#  '16462940': <data_utils.data_utils.Document at 0x1a1a1b01630>,
#  '16787536': <data_utils.data_utils.Document at 0x1a1a1c08e80>,
#  '17677002': <data_utils.data_utils.Document at 0x1a1a1d3e9e8>,
#  '16109169': <data_utils.data_utils.Document at 0x1a1a11dfe10>,
#  '17696610': <data_utils.data_utils.Document at 0x1a1a20a7668>,
#  '16517939': <data_utils.data_utils.Document at 0x1a1a224a828>,
#  '15882093': <data_utils.data_utils.Document at 0x1a1a2346358>}

# %%
fr3 = open('dataFiletest_docs.txt','rb')
test_docs = pickle.load(fr3)
test_docs

# %%
fr = open('dataFile.txt','rb')
label_bert = pickle.load(fr)
label_bert
# Out:
# array([[-0.11443339, -0.03196481,  0.0392308 , ..., -0.0862652 ,
#          0.10561264,  0.5380537 ],
#        [-0.2949803 ,  0.34131777, -0.34890535, ...,  0.17351934,
#         -0.22781236,  0.33362123],
#        [-0.06907637,  0.42193994,  0.16974014, ..., -0.07837002,
#         -0.28779513,  0.24101228],
#        ...,
#        [-0.16027017,  0.4593012 , -0.21587712, ...,  0.24038517,
#         -0.36521468, -0.14433114],
#        [-0.03436442, -0.0558713 , -0.27424845, ...,  0.50691897,
#          0.21578018,  0.35843298],
#        [-0.16290933, -0.2590604 , -0.31890228, ...,  0.10472322,
#         -0.10137611,  0.20134552]], dtype=float32)

# %%
fr2 = open('detaillabel.txt','rb')
detaillabel = pickle.load(fr2)
detaillabel
# Out:
# ['UBERON:0004340',
#  'CL:0002608',
#  'PR_EXT:000012924',
#  'PR_EXT:000004967',
#  'CL:0000100',
#  'GO:0008283',
#  'UBERON:0002179',
#  'GO:0046661',
#  'CL:0000136',
#  'PR_EXT:000003675',
#  'UBERON:0001982',
#  'GO_EXT:0005030',
#  'GO:0001171',
#  'GO_EXT:0015925',
#  'NCBITaxon:9606',
#  'CHEBI_CHMO_EXT:buffer_solution',
#  'CL:0000669',
#  'GO:0016265',
#  'UBERON:0004383',
#  'CHEBI:37926',
#  'CL:0000158',
#  'GO:0046879',
#  'PR_EXT:000005908',
#  'GO_EXT:0004565',
#  'GO_EXT:0005000',
#  'PR_EXT:000014394',
#  'PR_EXT:000006433',
#  'CL:0000169',
#  'UBERON:0002146',
#  'GO:0001889',
#  'CL:0000646',
#  'GO:0032391',
#  'GO:0008355',
#  'UBERON:0001757',
#  'PR_EXT:000001337',
#  'PR_EXT:000003676',
#  'CHEBI_PR_EXT:insulin_like_growth_factor_1',
#  'CL:0000189',
#  'SO_EXT:0000193',
#  'CHEBI_EXT:60816',
#  'GO:0050890',
#  'GO:0051716',
#  'GO:0007140',
#  'UBERON:0004114',
#  'GO:0097617',
#  'UBERON:0002073',
#  'PR_EXT:000016642',
#  'GO_SO_EXT:chromosomal_part_or_position_or_region_or_site',
#  'CL:0002518',
#  'GO:0002027',
#  'GO:0016234',
#  'GO:0030522',
#  'PR_EXT:000016321',
#  'NCBITaxon:27592',
#  'GO:0009888',
#  'GO_PR_EXT:growth_hormone_receptor',
#  'GO_SO_EXT:sequence_transposition_process',
#  'PR_EXT:000010242',
#  'CHEBI:48828',
#  'CHEBI:9750',
#  'PR_EXT:000015018',
#  'PR_EXT:Q9VHA0',
#  'CHEBI:86151',
#  'UBERON:0000013',
#  'UBERON:0000025',
#  'GO_PR_EXT:alkaline_phosphatase',
#  'GO:0016514',
#  'SO_EXT:sequence_circularization',
#  'UBERON:0003072',
#  'GO:0035822',
#  'NCBITaxon:9685',
#  'PR_EXT:000007050',
#  'CHEBI_EXT:52217',
#  'GO:0048870',
#  'UBERON:0009050',
#  'PR_EXT:000004825',
#  'GO:0007520',
#  'SO_EXT:sequence_fusion_process',
#  'GO:0008283',
#  'CHEBI:22868',
#  'GO:0015671',
#  'GO:0035791',
#  'UBERON:0002329',
#  'PR_EXT:000004915',
#  'UBERON:0005418',
#  'UBERON:0000916',
#  'UBERON:0001066',
#  'UBERON:0001439',
#  'GO:0097617',
#  'CHEBI:15377',
#  'PR_EXT:P04483',
#  'CHEBI:17334',
#  'PR_EXT:000016001',
#  'GO:0009888',
#  'GO:0007620',
#  'GO:0065007',
#  'GO:0042116',
#  'GO_EXT:0004984',
#  'SO_EXT:sequence_deletion_process',
#  'CL:0000670',
#  'CHEBI_EXT:argon',
#  'GO:0005712',
#  'CL:0000125',
#  'NCBITaxon:7955',
#  'GO:0010628',
#  'GO:0051716',
#  'UBERON:0000085',
#  'MOP:0000780',
#  'PR_EXT:000005591',
#  'GO:0006094',
#  'CHEBI_SO_EXT:peptide_or_peptide_region',
#  'UBERON:0003053',
#  'NCBITaxon:species',
#  'PR_EXT:000015288',
#  'SO_EXT:sequence_rescue_process',
#  'GO:0007568',
#  'UBERON_EXT:baby_or_infant',
#  'UBERON:0000924',
#  'CL:0000047',
#  'CHEBI:35696',
#  'GO_RO_EXT:developmental_differentiation_process',
#  'GO:0000724',
#  'PR_EXT:000006453',
#  'SO_EXT:transgenic_entity',
#  'UBERON:0002080',
#  'UBERON:0000025',
#  'UBERON:0000966',
#  'UBERON:0001842',
#  'SO_EXT:0000155',
#  'PR_EXT:P97779',
#  'CL:0010009',
#  'GO:0007417',
#  'PR_EXT:000005907',
#  'PR_EXT:000015393',
#  'CL:0000171',
#  'PR_EXT:000011459',
#  'CL:0000080',
#  'GO:0005634',
#  'PR_EXT:cyclin_D',
#  'GO_EXT:transfectant_or_tranformant',
#  'SO_EXT:0001060',
#  'GO:0007129',
#  'PR_EXT:000015477',
#  'GO_EXT:myelin_assembly_or_myelination',
#  'GO:0048840',
#  'PR_EXT:000000010',
#  'GO_MOP_EXT:catalysis',
#  'SO_EXT:genomic_DNA',
#  'PR_EXT:000001980',
#  'CHEBI:25698',
#  'CHEBI:15541',
#  'GO_EXT:cell_communication_or_signaling_or_signal_transduction',
#  'PR_EXT:000013709',
#  'GO:0008355',
#  'GO:0006415',
#  'GO:0098762',
#  'CHEBI:15889',
#  'CL:0000187',
#  'SO_EXT:0000407',
#  'GO:0097427',
#  'GO:0006281',
#  'GO:0035790',
#  'UBERON:0000044',
#  'UBERON:0002291',
#  'UBERON:0000104',
#  'CHEBI:7984',
#  'CHEBI_EXT:50114',
#  'PR_EXT:000014397',
#  'CL:0002613',
#  'GO_EXT:transcription_factor',
#  'CL:0002481',
#  'CHEBI:28304',
#  'SO_EXT:genotype_or_entity_with_genotype',
#  'SO_EXT:sequence_insertion_entity_or_process',
#  'PR_EXT:000015124',
#  'GO:0060612',
#  'CL:1001502',
#  'GO_UBERON_EXT:nerve_ending_or_neuron_projection_terminus',
#  'UBERON:0001062',
#  'UBERON:0003916',
#  'GO:0098762',
#  'CL:0002211',
#  'UBERON:0001781',
#  'PR_EXT:P10084',
#  'NCBITaxon:9255',
#  'PR_EXT:000001013',
#  'UBERON:0002091',
#  'GO:0046907',
#  'CL:0000178',
#  'CHEBI:9750',
#  'UBERON:0004347',
#  'CHEBI_PR_EXT:angiotensin',
#  'PR_EXT:000008536',
#  'SO:0001817',
#  'GO:0040007',
#  'UBERON:0001447',
#  'GO:0034772',
#  'GO:0048856',
#  'UBERON:0003666',
#  'CL:0000743',
#  'UBERON:0007616',
#  'GO_PR_EXT:ephrin_receptor',
#  'PR_EXT:000009322',
#  'GO:0030855',
#  'GO:0043491',
#  'PR_EXT:000004155',
#  'PR_EXT:000017448',
#  'PR_EXT:000015039',
#  'GO_PR_EXT:transforming_growth_factor_beta_receptor_type_II',
#  'GO:0019395',
#  'CHEBI:24866',
#  'UBERON:0001132',
#  'CL:0002488',
#  'GO:0043234',
#  'GO:0007143',
#  'PR_EXT:000005257',
#  'GO:0032991',
#  'PR_EXT:000007641',
#  'CHEBI_EXT:33893',
#  'PR_EXT:vascuar_endothelial_growth_factor',
#  'PR_EXT:000001933',
#  'NCBITaxon:31033',
#  'GO:0003408',
#  'PR_EXT:000004454',
#  'SO_EXT:0001023',
#  'GO_EXT:detection_or_sensing_of_mechanical_stimulus',
#  'GO_PR_EXT:insulin_receptor',
#  'CL:0000062',
#  'UBERON:0002257',
#  'PR_EXT:000001166',
#  'PR_EXT:000004825',
#  'UBERON:0002067',
#  'CHEBI_EXT:chemical_substance_or_polyatomic_entity',
#  'CL:0009004',
#  'PR_EXT:000007998',
#  'UBERON:0007688',
#  'UBERON:0004809',
#  'UBERON:0001245',
#  'PR_EXT:000004122',
#  'UBERON:0004288',
#  'GO:0001502',
#  'PR_EXT:000008043',
#  'GO_SO_EXT:sequence_rearrangement_process',
#  'CL:0002211',
#  'GO:0006342',
#  'PR_EXT:000002060',
#  'GO:0030154',
#  'GO:0001774',
#  'NCBITaxon_EXT:quail',
#  'CL:0000182',
#  'CHEBI:15889',
#  'GO:0065003',
#  'UBERON:0006658',
#  'UBERON:0007232',
#  'GO_EXT:0017136',
#  'UBERON:0001756',
#  'UBERON:0004145',
#  'CL:0002483',
#  'GO:0007411',
#  'UBERON:0003945',
#  'PR_EXT:000017435',
#  'NCBITaxon:10847',
#  'CL:0002573',
#  'UBERON:0007603',
#  'CHEBI_GO_EXT:hormone',
#  'GO:0001967',
#  'PR_EXT:000007778',
#  'UBERON:0002329',
#  'GO:0007616',
#  'UBERON:0001897',
#  'CHEBI_EXT:phosphatidylcholine',
#  'CHEBI_EXT:59132',
#  'CL:0000232',
#  'PR_EXT:000016321',
#  'PR_EXT:000002122',
#  'CL:0000589',
#  'CHEBI:51231',
#  'PR_EXT:000006043',
#  'GO:0006272',
#  'SO_EXT:0000345',
#  'CHEBI:15541',
#  'UBERON:0007195',
#  'PR_EXT:000012421',
#  'SO_EXT:missense_quality_or_entity',
#  'UBERON:0002082',
#  'NCBITaxon:31033',
#  'GO:0005777',
#  'PR_EXT:carbonic_anhydrase_2',
#  'GO:0007132',
#  'GO:0032391',
#  'GO:0006952',
#  'GO:0001741',
#  'GO:0014051',
#  'PR_EXT:000013058',
#  'PR_EXT:000004968',
#  'CL:0000171',
#  'GO:0005783',
#  'UBERON:0000978',
#  'UBERON:0002351',
#  'UBERON:0005967',
#  'UBERON:0004264',
#  'UBERON:0003075',
#  'SO_EXT:sequence_repeat_unit_or_region',
#  'GO_EXT:0008384',
#  'PR_EXT:000004143',
#  'UBERON:0001446',
#  'PR_EXT:000010124',
#  'UBERON:0002301',
#  'GO_RO_EXT:developmental_differentiation_process',
#  'GO:0036123',
#  'CL:0000349',
#  'NCBITaxon:7955',
#  'CHEBI_EXT:platinum',
#  'UBERON:0006378',
#  'GO_SO_EXT:chromosomal_part_or_position_or_region_or_site',
#  'NCBITaxon:32523',
#  'UBERON:0002107',
#  'CHEBI_EXT:dATP',
#  'GO_EXT:0015662',
#  'GO_SO_EXT:translational_stop_entity_or_process',
#  'GO:0007411',
#  'UBERON:0000966',
#  'PR_EXT:000016340',
#  'GO:0033202',
#  'UBERON:0005483',
#  'CHEBI:26536',
#  'PR_EXT:P03962',
#  'UBERON:0004044',
#  'CHEBI_EXT:51217',
#  'CL:0000019',
#  'SO_EXT:0001062',
#  'PR_EXT:000001383',
#  'UBERON:0024914',
#  'GO_EXT:neuron_development_or_generation',
#  'UBERON:0000203',
#  'GO:0036123',
#  'GO_EXT:DNA_replicator',
#  'GO:0007494',
#  'PR_EXT:000004667',
#  'CHEBI:4883',
#  'GO:0060013',
#  'UBERON:0000925',
#  'CHEBI_GO_EXT:biological_process_or_quality_or_role',
#  'PR_EXT:000010873',
#  'GO:0006813',
#  'PR_EXT:000000183',
#  'GO:0019835',
#  'PR_EXT:000004527',
#  'GO_EXT:reaction_or_response',
#  'CHEBI:34288',
#  'UBERON:0006022',
#  'UBERON:0003054',
#  'UBERON:0004864',
#  'UBERON:0016538',
#  'GO:0005675',
#  'PR_EXT:000008321',
#  'UBERON:0001049',
#  'CHEBI:6872',
#  'NCBITaxon:8296',
#  'UBERON:0001015',
#  'GO:0042116',
#  'PR_EXT:000001176',
#  'UBERON:0001233',
#  'SO:0000857',
#  'GO:0007169',
#  'PR_EXT:000016655',
#  'GO:0001774',
#  'CHEBI:5103',
#  'UBERON:0005805',
#  'GO:0005618',
#  'GO:0000502',
#  'CHEBI_EXT:metal',
#  'PR_EXT:Q61771',
#  'SO_EXT:sequence_substitution_process',
#  'PR_EXT:000003107',
#  'GO:0050890',
#  'GO:0009948',
#  'GO:0050817',
#  'UBERON:0001821',
#  'NCBITaxon:31031',
#  'UBERON:0000323',
#  'PR_EXT:000022190',
#  'MOP:0000569',
#  'PR_EXT:000013676',
#  'UBERON_EXT:muscle_structure_or_tissue',
#  'CHEBI_EXT:metal',
#  'SO_EXT:sequence_duplication_process',
#  'GO:0060119',
#  'GO_EXT:0015666',
#  'GO_RO_EXT:developmental_differentiation_process',
#  'CHEBI:4629',
#  'GO:0032991',
#  'PR_EXT:000013675',
#  'UBERON:0006658',
#  'CL:0002518',
#  'PR_EXT:000005082',
#  'UBERON_EXT:embryonic_stage_or_stage_part',
#  'CHEBI:15355',
#  'PR_EXT:000000681',
#  'GO_EXT:0004457',
#  'SO_EXT:0000854',
#  'UBERON:0002349',
#  'PR_EXT:000004182',
#  'PR_EXT:000005274',
#  'NCBITaxon:86599',
#  'UBERON:0001005',
#  'SO_EXT:sequence_rescue_process',
#  'PR_EXT:000029950',
#  'PR_EXT:000043452',
#  'PR_EXT:000009065',
#  'GO_SO_EXT:sequence_rearrangement_process',
#  'GO:0030168',
#  'SO_EXT:microsatellite_unit_or_region',
#  'GO_PR_EXT:acetylcholinesterase',
#  'UBERON:0002046',
#  'GO:0097009',
#  'CHEBI:17824',
#  'PR_EXT:000003675',
#  'SO_EXT:sequence_alteration_process',
#  'CHEBI_PR_EXT:gastrin',
#  'GO_EXT:0008511',
#  'GO:0002507',
#  'CL:0011113',
#  'CHEBI:30212',
#  'CHEBI:5291',
#  'GO:0007411',
#  'CL:0000103',
#  'PR_EXT:000005376',
#  'NCBITaxon:4751',
#  'PR_EXT:000007124',
#  'GO_SO_EXT:chromosomal_part_or_position_or_region_or_site',
#  'GO:0007565',
#  'UBERON:0001791',
#  'GO:0007416',
#  'CHEBI:51277',
#  'GO:0001966',
#  'UBERON:0001751',
#  'CL:1000617',
#  'UBERON:0002031',
#  'CHEBI:32958',
#  'NCBITaxon:40674',
#  'CL:0000598',
#  'CL:0000681',
#  'GO_SO_EXT:centromere_or_centromeric_region_or_centromeric_orientation',
#  'CL:0000138',
#  'UBERON:0001386',
#  'PR_EXT:Q12436',
#  'UBERON:0001037',
#  'UBERON:0000107',
#  'GO:0030168',
#  'CL:0000609',
#  'GO:0042384',
#  'CHEBI:9750',
#  'NCBITaxon:3193',
#  'CHEBI_EXT:73730',
#  'GO_SO_EXT:chromosomal_part_or_position_or_region_or_site',
#  'UBERON_EXT:skeletal_muscle_organ_or_tissue',
#  'PR_EXT:000005904',
#  'PR_EXT:P17536',
#  'CL:0002371',
#  'PR_EXT:BMP_type_1_receptor',
#  'PR_EXT:000003244',
#  'CHEBI_EXT:35717',
#  'NCBITaxon:7719',
#  'PR_EXT:000000164',
#  'SO_EXT:epigenetic_modification_entity',
#  'GO_SO_EXT:chromosomal_part_or_position_or_region_or_site',
#  'UBERON:0005942',
#  'PR_EXT:000016649',
#  'GO:0006754',
#  'CHEBI_EXT:anaesthetic_process',
#  'CL:0000127',
#  'CL:0000010',
#  'PR_EXT:000009158',
#  'CHEBI:3098',
#  'CHEBI:52661',
#  'GO:0007599',
#  'PR_EXT:000013708',
#  'PR_EXT:000006148',
#  'GO:0010467',
#  'UBERON:0002502',
#  'GO_EXT:negative_regulation',
#  'CHEBI:18035',
#  'GO:0031982',
#  'UBERON:0002084',
#  'UBERON:0002227',
#  'GO_PR_EXT:pancreatic_ribonuclease_or_ribonuclease_A',
#  'CHEBI:50845',
#  'PR_EXT:000000167',
#  'GO_EXT:0042054',
#  'PR_EXT:000000046',
#  'GO:0034675',
#  'UBERON:0002168',
#  'UBERON:0001103',
#  'UBERON:0002541',
#  'UBERON_EXT:lens',
#  'GO_EXT:0004872',
#  'CL:0010001',
#  'UBERON:0001772',
#  'UBERON:0002048',
#  'PR_EXT:000009655',
#  'GO_EXT:0004984',
#  'SO_EXT:0000006',
#  'CL:0000586',
#  'GO:0006338',
#  'CL:0000300',
#  'SO_EXT:0000319',
#  'UBERON:0002819',
#  'GO:0042088',
#  'GO_EXT:0015267',
#  'GO_EXT:0004708',
#  'UBERON:0000105',
#  'CHEBI_EXT:succinate',
#  'UBERON:0001018',
#  'UBERON:0000210',
#  'PR_EXT:000007131',
#  'GO:0048538',
#  'UBERON:0002103',
#  'GO:0016567',
#  'CL:0010012',
#  'CHEBI_GO_EXT:histone_deacetylase_inhibitor',
#  'GO_EXT:0016787',
#  'NCBITaxon_UBERON_EXT:chick',
#  'GO_EXT:0015267',
#  'GO:0005856',
#  'GO:0044849',
#  'GO:0007126',
#  'GO:0005802',
#  'CHEBI_EXT:paraformaldehye',
#  'PR_EXT:000011536',
#  'PR_EXT:000044061',
#  'CHEBI:64583',
#  'CL:0000015',
#  'CHEBI:32139',
#  'GO:0019395',
#  'GO_EXT:positive_regulator',
#  'GO:0030154',
#  'GO:0031225',
#  'CHEBI:36357',
#  'GO_PR_EXT:androgen_receptor',
#  'PR_EXT:000013709',
#  'PR_EXT:000011508',
#  'CHEBI_SO_EXT:deoxyoligonucleotide',
#  'GO:0022008',
#  'UBERON:0003451',
#  'PR_EXT:000037797',
#  'PR_EXT:parvalbumin',
#  'PR_EXT:000014390',
#  'GO:0060819',
#  'CHEBI:28748',
#  'UBERON:0009912',
#  'UBERON:0001782',
#  'UBERON:0000305',
#  'GO:0071159',
#  'UBERON:0001846',
#  'GO:0006402',
#  'CL:0000855',
#  'UBERON:0006207',
#  'CHEBI_SO_EXT:N_terminus_or_N_terminal_region',
#  'SO_EXT:0000771',
#  'PR_EXT:000010764',
#  'CHEBI_EXT:oxygen',
#  'UBERON_EXT:zone_of_skin_or_skin_of_body',
#  'PR_EXT:000027234',
#  'PR_EXT:000004518',
#  'GO:0001741',
#  'GO:0035162',
#  'PR_EXT:000013249',
#  'NCBITaxon:10359',
#  'UBERON:0014626',
#  'UBERON:0002370',
#  'GO:0008219',
#  'CHEBI:5118',
#  'UBERON:0002532',
#  'UBERON:0000088',
#  'GO:0016604',
#  'GO:0044420',
#  'CHEBI_PR_EXT:amyloid_beta',
#  'PR_EXT:000011196',
#  'UBERON:0001819',
#  'PR_EXT:000035365',
#  'GO:0030016',
#  'SO_EXT:0000409',
#  'CHEBI:75508',
#  'SO_EXT:splice_acceptor',
#  'PR_EXT:Q02013',
#  'PR_EXT:000004642',
#  'GO:0051028',
#  'PR_EXT:000036337',
#  'GO_PR_EXT:diacylglycerol_acyltransferase',
#  'GO_EXT:0005044',
#  'CL:0000234',
#  'PR_EXT:000024939',
#  'GO_SO_EXT:centromere_or_centromeric_region_or_centromeric_orientation',
#  'GO_EXT:double_trimer_macromolecular_complex',
#  'UBERON:0000947',
#  'CHEBI_GO_EXT:low_density_lipoprotein_particle',
#  'GO_EXT:0008240',
#  'SO_EXT:physical_mapping_process',
#  'PR_EXT:000010159',
#  'CHEBI:74537',
#  'GO:0005634',
#  'PR_EXT:000013639',
#  'UBERON:0005434',
#  'UBERON:0013235',
#  'PR_EXT:000010184',
#  'UBERON:0003089',
#  'NCBITaxon:12124',
#  'GO_PR_EXT:glutathione_S_transferase',
#  'CHEBI_EXT:37527',
#  'UBERON:0001987',
#  'SO_EXT:0001587',
#  'SO_EXT:0100019',
#  'SO_EXT:coding_sequence',
#  'GO_EXT:phosphoglycerate_kinase',
#  'PR_EXT:000005402',
#  'CHEBI:30563',
#  'GO:0010467',
#  'UBERON_EXT:hippocampus_proper_or_hippocampal_formation',
#  'GO:0005930',
#  'CHEBI_EXT:uracil_nucleobase_or_nucleoside_or_nucleotide_molecular_entity_or_group',
#  'UBERON:0004027',
#  'CHEBI:17968',
#  'SO_EXT:0000997',
#  'PR_EXT:000010686',
#  'PR_EXT:000004789',
#  'GO:0001764',
#  'SO:0000993',
#  'GO_EXT:0015026',
#  'UBERON:0004364',
#  'CHEBI_EXT:radiolabel_process',
#  'GO:0006413',
#  'SO_EXT:0000028',
#  'UBERON:0001781',
#  'GO_EXT:neurotransmission',
#  'GO:0016192',
#  'SO_EXT:0000852',
#  'PR_EXT:000013523',
#  'CHEBI:35366',
#  'UBERON:0004288',
#  'CL:0000771',
#  'CHEBI_EXT:tungsten',
#  'PR_EXT:000016008',
#  'UBERON:0000106',
#  'SO_EXT:0000333',
#  'CL:0000740',
#  'UBERON:0002178',
#  'NCBITaxon:10116',
#  'GO:0097440',
#  'SO_EXT:sequence_inversion_entity_or_process',
#  'CHEBI_EXT:metal',
#  'CHEBI:35186',
#  'CHEBI_SO_EXT:methionine',
#  'PR_EXT:000004145',
#  'PR_EXT:000015906',
#  'NCBITaxon:6239',
#  'CL:0000359',
#  'GO_PATO_EXT:biological_patterning_process_or_quality',
#  'CHEBI:24009',
#  'GO:0051216',
#  'GO:0048539',
#  'UBERON:0001737',
#  'GO:0005730',
#  'PR_EXT:000007772',
#  'CHEBI:62964',
#  'UBERON:0002410',
#  'GO_SO_EXT:chromosomal_part_or_position_or_region_or_site',
#  'CL:0002228',
#  'MOP:0000568',
#  'UBERON:0000366',
#  'MOP:0000779',
#  'GO_PR_EXT:7_dehydrocholesterol_reductase',
#  'UBERON:0001132',
#  'GO:0016055',
#  'CHEBI:46261',
#  'GO:1990391',
#  'SO_EXT:0000317',
#  'SO_EXT:0000610',
#  'NCBITaxon:3704',
#  'UBERON:0001851',
#  'GO:0042571',
#  'GO:0070734',
#  'PR_EXT:000004168',
#  'PR_EXT:000010246',
#  'NCBITaxon:7656',
#  'GO:0005913',
#  'CHEBI_EXT:86029',
#  'SO_EXT:sequence_deletion_process',
#  'SO_EXT:0000646',
#  'CHEBI_EXT:citrate',
#  'GO:0010941',
#  'UBERON:0024914',
#  'GO:0048339',
#  'PR_EXT:000013665',
#  'PR_EXT:000007227',
#  'UBERON:0014387',
#  'PR_EXT:000027234',
#  'GO:0016265',
#  'GO_EXT:0005125',
#  'CHEBI:46662',
#  'CL:0000189',
#  'UBERON:0000948',
#  'GO_EXT:0005031',
#  'UBERON:0001211',
#  'PR_EXT:000009116',
#  'SO_EXT:0000162',
#  'GO:0007169',
#  'UBERON:0000118',
#  'SO_EXT:0000154',
#  'GO:0006900',
#  'GO_PR_EXT:transforming_growth_factor_beta_receptor_type_I',
#  'GO:0006412',
#  'NCBITaxon:33208',
#  'SO_EXT:0000018',
#  'CL:0000635',
#  'SO_EXT:wild_type_entity_or_quality',
#  'CHEBI_SO_EXT:N_terminus_or_N_terminal_region',
#  'SO_EXT:satellite_unit_or_region',
#  'GO:0048565',
#  'CHEBI:15765',
#  'CL:0000233',
#  'PR_EXT:000002312',
#  'UBERON:0005932',
#  'CL:0000609',
#  'CL:0000540',
#  'PR_EXT:000006854',
#  'CHEBI:22918',
#  'PR_EXT:000007623',
#  'GO:0046541',
#  'PR_EXT:000013555',
#  'GO:0042384',
#  'UBERON:0000088',
#  'GO:0043227',
#  'CL:0002327',
#  'GO:0005634',
#  'PR_EXT:000015322',
#  'GO_EXT:0004407',
#  'SO_EXT:sequence_altered_entity',
#  'PR_EXT:000002088',
#  'CL:0000017',
#  'SO_EXT:sequence_truncation_entity_or_process',
#  'PR_EXT:000007130',
#  'PR_EXT:ELMO',
#  'PR_EXT:O18214',
#  'PR_EXT:000005009',
#  'UBERON:0002323',
#  'UBERON:0000060',
#  'UBERON:0000467',
#  'GO:0090307',
#  'CL:0002242',
#  'CL:0000681',
#  'GO:0060396',
#  'UBERON:0013235',
#  'UBERON:0005313',
#  'CHEBI:32031',
#  'PR_EXT:000000216',
#  'PR_EXT:000011471',
#  'GO:0009048',
#  'UBERON:0007651',
#  'UBERON:0002069',
#  'SO_EXT:0000954',
#  'GO:0005731',
#  'GO:0042555',
#  'GO:0001654',
#  'CL:0000001',
#  'CL:0002212',
#  'GO_PATO_EXT:phosphorylation_process_or_quality',
#  'SO_EXT:biological_conservation_process_or_quality',
#  'PR_EXT:000013159',
#  'NCBITaxon:38323',
#  'SO_EXT:wild_type_entity_or_quality',
#  'SO_EXT:sequence_alteration_process',
#  'GO:0031045',
#  'PR_EXT:000011536',
#  'GO:0001570',
#  'PR_EXT:000002058',
#  'GO_EXT:biological_release',
#  'CHEBI_SO_EXT:C_terminus_or_C_terminal_region',
#  'PR_EXT:000006901',
#  'NCBITaxon:10442',
#  'PR_EXT:000005402',
#  'CHEBI:35607',
#  'GO:0030424',
#  'GO:0048665',
#  'GO_EXT:biological_routing_or_transport',
#  'CL:0000745',
#  'UBERON:0002094',
#  'GO:0070507',
#  'UBERON:0001782',
#  'GO:0065003',
#  'PR_EXT:000003439',
#  'GO:0005911',
#  'GO_EXT:tight_junction',
#  'CHEMINF_GO_EXT:chemical_binding_or_bond_formation',
#  'CL:0000312',
#  'UBERON:0003123',
#  'CL:0000025',
#  'CL_GO_EXT:cell',
#  'GO:0048821',
#  'GO:0007129',
#  'CHEBI:8102',
#  'PR_EXT:000008813',
#  'CL:0002092',
#  'PR_EXT:000008278',
#  'GO:0051318',
#  'SO_EXT:biological_sequence',
#  'PR_EXT:000004454',
#  'PR_EXT:000001016',
#  'UBERON:0001766',
#  'CHEBI:8502',
#  'UBERON:0003655',
#  'CHEBI:15346',
#  'UBERON:0002020',
#  'GO_SO_EXT:chromosomal_part_or_position_or_region_or_site',
#  'UBERON:0008959',
#  'PR_EXT:000001479',
#  'GO:0043631',
#  'PR_EXT:000002032',
#  'PR_EXT:000007680',
#  'PR_EXT:000001177',
#  'GO_EXT:0045289',
#  'PR_EXT:000001992',
#  'UBERON:0001225',
#  'UBERON:0000006',
#  'UBERON:0002314',
#  'GO:0006412',
#  'SO_EXT:1001187',
#  'PR_EXT:000012946',
#  'GO:0007411',
#  'SO_EXT:sequence_linearization',
#  'PR_EXT:000022460',
#  'GO:0008610',
#  'PR_EXT:000009640',
#  'GO:0070498',
#  'PR_EXT:000007920',
#  'UBERON:0003126',
#  'GO:0001582',
#  'UBERON:0011905',
#  'PR_EXT:000005835',
#  'GO:0000380',
#  'PR_EXT:000013059',
#  'GO:0042384',
#  'GO:0005662',
#  'UBERON:0001016',
#  'CHEBI:18035',
#  'UBERON:0002100',
#  'PR_EXT:000004978',
#  'GO:0045177',
#  'UBERON:0003915',
#  'UBERON:0002836',
#  'GO_SO_EXT:chromosomal_part_or_position_or_region_or_site',
#  'CHEBI_CHMO_EXT:buffer_process',
#  'CHEBI_EXT:47867',
#  'PR_EXT:000005644',
#  'PR_EXT:000015919',
#  'PR_EXT:ROBO',
#  'CHEBI:16247',
#  'PR_EXT:000005591',
#  'CL:0000235',
#  'GO:0060539',
#  'NCBITaxon:species',
#  'PR_EXT:000011059',
#  'CL:0002492',
#  'GO_EXT:beta_geo',
#  'PR_EXT:000007102',
#  'PR_EXT:000010903',
#  'GO:0019915',
#  'GO:0001568',
#  'UBERON:0002124',
#  'UBERON:0002424',
#  'CHEBI:16236',
#  'CHEBI:17759',
#  'GO_EXT:0008066',
#  'GO:0000805',
#  'PR_EXT:000007857',
#  'GO:0008543',
#  'NCBITaxon:subspecies',
#  'UBERON:0000948',
#  'CHEBI:78021',
#  'CHEBI_SO_EXT:molecular_probe',
#  'SO_EXT:0000141',
#  'UBERON:0004154',
#  'CHEBI_EXT:26130',
#  'UBERON:0003104',
#  'CHEBI_EXT:23888',
#  'UBERON:0001757',
#  'GO_EXT:biological_routing_or_transport',
#  'SO_EXT:0000336',
#  'UBERON:0001389',
#  'GO:0001967',
#  'CHEBI:26519',
#  'SO_EXT:0001830',
#  'CHEBI_EXT:phosphoprotein',
#  'CL:0000776',
#  'UBERON:0001809',
#  'UBERON:0000105',
#  'CL:0000746',
#  'GO:0043584',
#  'UBERON:0001789',
#  'PR_EXT:000013042',
#  'CL_EXT:neural_crest_cell',
#  'GO:0014069',
#  'PR_EXT:000001968',
#  'GO:0006915',
#  'GO:0032391',
#  'UBERON:0000204',
#  'CHEBI_SO_EXT:inosine',
#  'GO:0007530',
#  'GO_EXT:0004175',
#  'SO_EXT:0001415',
#  'SO_EXT:0000363',
#  'CL:0000542',
#  'UBERON:0001040',
#  'CL:0002608',
#  'GO:0071944',
#  'PR_EXT:000025844',
#  'GO:0001525',
#  'GO:0030166',
#  'PR_EXT:000001447',
#  'UBERON:0001522',
#  'UBERON:0003888',
#  'PR_EXT:000003263',
#  'GO:0006750',
#  'PR_EXT:000000118',
#  'GO:0072672',
#  'UBERON:0000328',
#  'PR_EXT:000011459',
#  'CL:0000097',
#  'GO:0007618',
#  'GO_EXT:regulator',
#  'CHEBI:81588',
#  'PR_EXT:000001669',
#  'CHEBI_EXT:33290',
#  'NCBITaxon:9031',
#  'PR_EXT:000003675',
#  'GO:0008406',
#  'GO:0016604',
#  'SO:0000984',
#  'GO:0007224',
#  'NCBITaxon:7668',
#  'UBERON:0001905',
#  'UBERON:0004347',
#  'PR_EXT:000007786',
#  'UBERON:0011919',
#  'CHEBI:57472',
#  'CL:0002540',
#  'SO_EXT:0000188',
#  'CHEBI_SO_EXT:glutamic_acid',
#  'PR_EXT:000002385',
#  'UBERON:0001447',
#  'UBERON:0010230',
#  'GO_EXT:biological_movement_or_translocation_process',
#  'GO:0005622',
#  'UBERON:0002435',
#  'GO:0005634',
#  'UBERON:0001833',
#  'SO_EXT:0000409',
#  'GO:0001775',
#  'GO_EXT:0004784',
#  'GO:0034683',
#  'GO:0048538',
#  'PR_EXT:000001091',
#  'GO_EXT:0004457',
#  'UBERON:0000915',
#  'GO:0048568',
#  'SO_EXT:sequence_coding_function',
#  'SO_EXT:0001421',
#  'UBERON:0002926',
#  'CL:1001451',
#  'UBERON:0010166',
#  'PR_EXT:000013530',
#  'UBERON:0008979',
#  'UBERON:0002046',
#  'PR_EXT:NXF',
#  'PR_EXT:000012583',
#  'CL:1000426',
#  'NCBITaxon:11138',
#  'UBERON:0005107',
#  'PR_EXT:000014413',
#  'GO:0005912',
#  'GO:0045087',
#  'PR_EXT:000005836',
#  'GO:0001578',
#  'NCBITaxon:9606',
#  'PR_EXT:000004837',
#  'UBERON:0004381',
#  'UBERON:0000966',
#  'UBERON:0000211',
#  'SO_EXT:0000831',
#  'GO:0060173',
#  'UBERON:0001969',
#  'UBERON:0001007',
#  'GO:0007565',
#  'UBERON:0019252',
#  'PR_EXT:000005643',
#  'PR_EXT:SLIT',
#  'PR_EXT:000007070',
#  'GO_SO_EXT:chromosomal_part_or_position_or_region_or_site',
#  'CL:0000010',
#  'UBERON:0006860',
#  ...]

# %%
from bert_serving.client import BertClient
from sklearn.metrics.pairwise import cosine_similarity
bc = BertClient()

# %%
import numpy as np

# %%
#存储每个文件中 每个大分类的字符串
str_entcategory_text=dict()
for fileName in pred_docs.keys():
    str_entcategory_text[fileName]=[]
    for i in range(len(pred_docs[fileName].ents.ents)):
        string = pred_docs[fileName].ents.ents[i].category+" "+pred_docs[fileName].ents.ents[i].text
        str_entcategory_text[fileName].append(string)
str_entcategory_text
# Out:
# {'16362077': ['PR_EXT Sam68',
#   'CHEBI_SO_EXT RNA',
#   'CHEMINF_GO_EXT Binding',
#   'CHEBI_PR_EXT Protein',
#   'NCBITaxon Mice',
#   'UBERON_EXT Bone',
#   'PR_EXT Src',
#   'GO mimitos',
#   'CHEBI_SO_EXT RNA',
#   'CHEMINF_GO_EXT binding',
#   'CHEBI_PR_EXT protein',
#   'GO regulate',
#   'GO RNA metabolism',
#   'GO_PATO_EXT physiologic',
#   'PR_EXT Sam68',
#   'SO_EXT null',
#   'NCBITaxon mice',
#   'GO_SO_EXT recombination',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'UBERON_EXT bone',
#   'SO_EXT wild-type',
#   'UBERON_EXT bone',
#   'UBERON_EXT bone',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'SO_EXT wild-type',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'UBERON bone bone m',
#   'CL stromal ',
#   'CL_GO_EXT cells',
#   'GO_RO_EXT differentiation',
#   'GO ostosteoge',
#   'PR_EXT Sam68',
#   'PR_EXT hairp',
#   'CHEBI_SO_EXT RNA',
#   'UBERON embryonic',
#   'UBERON mesenchymal',
#   'CL_GO_EXT cells',
#   'GO expression',
#   'CL osteoblast',
#   'CHEBI_SO_EXT marker',
#   'CHEBI osteocalcin',
#   'GO_RO_EXT differentiation',
#   'PR_EXT bone morphogenetic ',
#   'CHEBI_PR_EXT protein',
#   'PR_EXT -2',
#   'NCBITaxon mouse',
#   'UBERON embryo',
#   'CL fibroblasts',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT +',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'GO_RO_EXT differentiate',
#   'CL adipocytes',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mouse',
#   'UBERON embryo',
#   'CL fibroblastf',
#   'CL adipocyte',
#   'GO_RO_EXT differentiation',
#   'UBERON bone',
#   'PR_EXT SaSam',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'CL adipocytes',
#   'SO_EXT wild-type',
#   'UBERON bone',
#   'PR_EXT Sam68',
#   'GO_EXT regregula',
#   'CL adipocyte',
#   'GO_RO_EXT differentiation',
#   'GO_EXT regulator',
#   'CL osteoblast',
#   'GO_RO_EXT differentiation',
#   'PR_EXT Sam68',
#   'GO_EXT modulator',
#   'UBERON_EXT bone',
#   'UBERON mesenchymal',
#   'GO cell',
#   'GO_RO_EXT differentiation',
#   'UBERON_EXT bone',
#   'GO metabolism',
#   'GO_PATO_EXT aged',
#   'NCBITaxon mice',
#   'UBERON_EXT bbon',
#   'UBERON_EXT bone',
#   'UBERON_EXT bone',
#   'NCBITaxon humans',
#   'NCBITaxon mice',
#   'PR_EXT Sam68',
#   'CHEBI_SO_EXT RNR',
#   'CHEMINF_GO_EXT binding',
#   'CHEBI_PR_EXT protein',
#   'CHEBI_PR_EXT protein',
#   'GO_PATO_EXT physiologic',
#   'NCBITaxon mice',
#   'GO aging',
#   'UBERON bone',
#   'CL adipocytes',
#   'UBERON mesenchymal',
#   'CL osteoblasts',
#   'UBERON bone marrow',
#   'PR_EXT Sam68',
#   'GO_EXT regulates',
#   'GO_RO_EXT differentiation',
#   'GO  of this ',
#   'UBERON mesenchymme',
#   'CL osteoblasts',
#   'GO aging',
#   'UBERON_EXT bone',
#   'GO_PATO_EXT physiologic',
#   'PR_EXT Sam68',
#   'GO_EXT modulatmo',
#   'UBERON bone marrow',
#   'CL_GO_EXT cell',
#   'UBERON_EXT bone',
#   'GO metabolime',
#   'UBERON bone',
#   'GO skeletal development',
#   'CL ososteoblas',
#   'GO catabolic',
#   'CL osteoclaost',
#   'UBERON_EXT bone',
#   'UBERON skeletal',
#   'UBERON_EXT bone',
#   'CL osteoblasts',
#   'CL osteoclasts',
#   'GO remodeling cycle',
#   'GO skeletal aging',
#   'GO osteoblast',
#   'UBERON bone',
#   'UBERON_EXT bone',
#   'GO aging',
#   'OBI_SO_EXT genegene',
#   'GO response of ',
#   'UBERON_EXT bone ',
#   'CL_GO_EXT cells',
#   'GO circulating h',
#   'CHEBI_GO_EXT ormonho',
#   'GO_EXT growth factors',
#   'SO_EXT gengene',
#   'GO regulate',
#   'GO_EXT bone development',
#   'UBERON bone',
#   'UBERON_EXT bone',
#   'GO bone resorp',
#   'NCBITaxon_UBERON_EXT women',
#   'UBERON_EXT bone',
#   'UBERON_EXT bone',
#   'CHEBI_SO_EXT bbiomarker',
#   'PR_EXT parathyroid',
#   'UBERON gonadal',
#   'CHEBI_GO_EXT hormone',
#   'CHEBI_PR_EXT leptin',
#   'UBERON sympathetic nervous',
#   'UBERON_EXT bone',
#   'GO cell apoptosis',
#   'GO_EXT respons',
#   'GO respo',
#   'UBERON_EXT bone',
#   'CL stromal ',
#   'CL_GO_EXT cells',
#   'GO_RO_EXT differentiation',
#   'CL adipocyte',
#   'CL osteoblast',
#   'GO Aging',
#   'CHEBI_UBERON_EXT fat',
#   'CL adipocytes',
#   'CL osteoblasts',
#   'CL Osteoblasts',
#   'CL adipocytes',
#   'UBERON mesenchymal',
#   'CL_GO_EXT cell',
#   'UBERON bone ma',
#   'GO control',
#   'GO adipogenic',
#   'GO_RO_EXT differentiation',
#   'GO_EXT transcriptional',
#   'GO regulatory',
#   'CHEBI_PR_EXT proteins',
#   'CL_GO_EXT cell',
#   'UBERON bone marrow mesenchymal',
#   'CL_GO_EXT cells',
#   'PR_EXT peroxisome proliferator–activated receptor γ',
#   'PR_EXT PPARγ',
#   'PR_EXT KLF5',
#   'CHEBI_SO_EXT RNA',
#   'CHEMINF_GO_EXT binding',
#   'CHEBI_PR_EXT proteins',
#   'CHEBI_SO_EXT RNA',
#   'CHEMINF_GO_EXT binding',
#   'CHEBI_PR_EXT proteins',
#   'SO_EXT type',
#   'GO_EXT regulators',
#   'GO cellular differentiation',
#   'GO expression',
#   'SO_EXT domain',
#   'CHEBI_PR_EXT proteins',
#   'PR_EXT FMRP',
#   'UBERON neurologic',
#   'GO X s',
#   'NCBITaxon humans',
#   'NCBITaxon mice',
#   'CHEBI_SO_EXT RNA',
#   'CHEMINF_GO_EXT binding',
#   'CHEBI_PR_EXT protpro',
#   'CL oligodendrocytes',
#   'GO_EXT myelination',
#   'GO expression',
#   'PR_EXT QKI-6',
#   'SO_EXT isoforms',
#   'CL glial ',
#   'CL_GO_EXT cells',
#   'CL neurons',
#   'GO cell fate determination',
#   'PR_EXT GLD-1',
#   'CHEBI_PR_EXT protein',
#   'NCBITaxon Caenorhabditis elegans',
#   'CL stem ',
#   'CL_GO_EXT cells',
#   'SO_EXT domain',
#   'CHEBI_PR_EXT protein',
#   'PR_EXT HOH',
#   'NCBITaxon Drosophila',
#   'UBERON_EXT muscle',
#   'GO_RO_EXT differentiation',
#   'UBERON wings',
#   'PR_EXT Src',
#   'GO mitosis',
#   'SO_EXT domain',
#   'CHEBI_SO_EXT RNA',
#   'CHEMINF_GO_EXT binding',
#   'CHEBI_PR_EXT proteins',
#   'GO_PATO_EXT physiologic',
#   'SO_EXT domain',
#   'CHEBI_PR_EXT protein',
#   'PR_EXT Src family ',
#   'GO_EXT kinases',
#   'PR_EXT Src ',
#   'GO_EXT kinases',
#   'GO_EXT tumor ',
#   'PR_EXT Sam68',
#   'SO_EXT spliced HIV',
#   'CHEBI_SO_EXT RNA',
#   'GO regulate',
#   'CHEBI_SO_EXT mRNA',
#   'SO_EXT processing',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'UBERON skeletal',
#   'PR_EXT Sam68',
#   'UBERON bone',
#   'NCBITaxon mice',
#   'PR_EXT Sam68',
#   'SO_EXT wild-type',
#   'PR_EXT Sam68',
#   'GO_EXT regulates',
#   'GO differentiation of ',
#   'CL bone marrow stromal ',
#   'CL_GO_EXT cells',
#   'CL_GO_EXT cells',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon animals',
#   'GO osteogenic',
#   'SO_EXT wild-type',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mouse',
#   'UBERON embryo',
#   'CL fibfibrobla',
#   'GO_RO_EXT differentiate',
#   'CL adipocytes',
#   'PR_EXT Sam68',
#   'GO_EXT regulator',
#   'UBERON bon',
#   'UBERON_EXT b',
#   'UBERON mesenchymal',
#   'GO cell differentiation',
#   'NCBITaxon animal',
#   'GO metabolism',
#   'GO regenerarege',
#   'GO repair',
#   'GO aging',
#   'PR_EXT Sam68',
#   'GO Expressed',
#   'UBERON Embryonic',
#   'NCBITaxon Mice',
#   'PR_EXT Sam68',
#   'CHEBI_SO_EXT mRNA',
#   'GO expressed',
#   'CHEBI_PR_EXT protein',
#   'GO exexpressi',
#   'SO_EXT wild-type',
#   'UBERON embryonic',
#   'NCBITaxon mice',
#   'PR_EXT Sam68',
#   'GO antibody',
#   'NCBITaxon rabbits',
#   'CHEBI_SO_EXT peptide',
#   'CHEBI_SO_EXT aminoamino ',
#   'NCBITaxon mouse',
#   'PR_EXT Sam68',
#   'CHEBI_PR_EXT protein',
#   'UBERON skeleton',
#   'UBERON tissues',
#   'SO_EXT wild-type',
#   'NCBITaxon mice',
#   'GO nucleus',
#   'CL_GO_EXT cells',
#   'UBERON brain',
#   'UBERON hhear',
#   'UBERON small intestine',
#   'CL chondrocyteh',
#   'UBERON nasal septum',
#   'UBERON glandular',
#   'UBERON tissue',
#   'UBERON nnasal cartilag',
#   'UBERON vertebra',
#   'UBERON intervertebral d',
#   'UBERON long bones',
#   'GO Nuclear',
#   'GO proliferating',
#   'CL chondrocytes',
#   'CL hypertrophic chondrocyteh',
#   'CL osteoblasts',
#   'CL osteoclasts',
#   'UBERON serum',
#   'UBERON serum',
#   'CHEBI_SO_EXT peptide',
#   'PR_EXT Sam68',
#   'CHEBI_PR_EXT protein',
#   'GO expressex',
#   'NCBITaxon mouse',
#   'UBERON embryo',
#   'GO exexpressi',
#   'UBERON cartilage',
#   'UBERON_EXT bone',
#   'NCBITaxon MousM',
#   'GO_PATO_EXT physiologic',
#   'PR_EXT Sam68',
#   'PR_EXT Sam68',
#   'NCBITaxon mice',
#   'SO_EXT exons',
#   'PR_EXT sam68',
#   'SO_EXT gene',
#   'SO_EXT encode',
#   'PR_EXT KKH-t',
#   'SO_EXT pe',
#   'CHEBI_SO_EXT RNA',
#   'CHEMINF_GO_EXT binding',
#   'SO_EXT domain',
#   'SO_EXT allele',
#   'SO_EXT genomic ',
#   'CHEBI_SO_EXT DNA',
#   'SO_EXT transcripts',
#   'SO_EXT eencode',
#   'SO_EXT exons',
#   'GO_EXT RT',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'PR_EXT Sam68',
#   'CHEBI_PR_EXT protein',
#   'PR_EXT Sam68',
#   'GO antibodiea',
#   'NCBITaxon rabbit',
#   'UBERON serum',
#   'PR_EXT Sam68 AD1',
#   'CHEBI_SO_EXT peptide',
#   'NCBITaxon rabbit',
#   'PR_EXT Sam68',
#   'GO antibody',
#   'CHEBI_SO_EXT C-terminal',
#   'CHEBI_SO_EXT amino acids',
#   'PR_EXT Sam68',
#   'NCBITaxon mouse',
#   'SO_EXT genotypes',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon_UBERON_EXT pups',
#   'GO died',
#   'GO birth',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT -',
#   'NCBITaxon mice',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon_UBERON_EXT pups',
#   'UBERON peri',
#   'GO natal',
#   'PR_EXT Sam68',
#   'CHEBI_SO_EXT mRNA',
#   'GO expressed',
#   'GO_PATO_EXT phosphorylated',
#   'GO mitosis',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mimi',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'GO_EXT breedibr',
#   'PATO_UBERON_EXT male',
#   'PATO_UBERON_EXT females',
#   'PR_EXT Sam68',
#   'NCBITaxon Mice',
#   'UBERON_EXT Bone',
#   'PR_EXT Src',
#   'SO_EXT null',
#   'NCBITaxon animals',
#   'GO metmetabol',
#   'PR_EXT Sam68',
#   'PR_EXT Src',
#   'NCBITaxon mice',
#   'UBERON skeletal',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT +',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'UBERON skeletal',
#   'UBERON_EXT bone',
#   'PATO_UBERON_EXT female',
#   'NCBITaxon mice',
#   'PATO_UBERON_EXT female',
#   'NCBITaxon mice',
#   'UBERON_EXT body',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'PR_EXT SaSam',
#   'SO_EXT +',
#   'SO_EXT +',
#   'NCBITaxon mice',
#   'UBERON_EXT bone',
#   'UBERON skeleton',
#   'UBERON cortical',
#   'UBERON metaphyse',
#   'UBERON_EXT bone',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT +',
#   'NCBITaxon mice',
#   'NCBITaxon micm',
#   'SO_EXT genotype',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'UBERON trabecular bone',
#   'UBERON lumbar vertebrae',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT +',
#   'NCBITaxon mice',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'UBERON body bone ',
#   'CHEBI mineral',
#   'NCBITaxon mouse',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT +',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'UBERON femur',
#   'NCBITaxon vertebra',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'UBERON Bone',
#   'SO_EXT wild type',
#   'NCBITaxon mice',
#   'UBERON_EXT body',
#   'UBERON vevertebr',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'UBERON skeleton',
#   'UBERON_EXT bone',
#   'NCBITaxon Bone',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon Mice',
#   'UBERON skeletons',
#   'GO_PATO_EXT aged',
#   'NCBITaxon mice',
#   'UBERON bone',
#   'NCBITaxon humans',
#   'UBERON_EXT bone',
#   'UBERON tissue',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT +',
#   'NCBITaxon mice',
#   'NCBITaxon mice',
#   'SO_EXT genotypes',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'UBERON trabecular',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT +',
#   'NCBITaxon mice',
#   'UBERON Trabecular',
#   'NCBITaxon mice',
#   'UBERON trabeculae',
#   'UBERON trabeculae',
#   'PR_EXT SamSa',
#   'SO_EXT +',
#   'SO_EXT +',
#   'NCBITaxon mice',
#   'NCBITaxon mice',
#   'GO Bone Remod',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon Mice',
#   'UBERON_EXT bone',
#   'GO_PATO_EXT agea',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'CL osteoblast',
#   'CHEBI_GO_SO_EXT enzyme',
#   'GO_PR_EXT alkaline phospline p',
#   'PR_EXT ALP',
#   'CHEBI_SO_EXT biomarker',
#   'CL oosteoblast',
#   'PR_EXT ALP',
#   'CHEBI acid p',
#   'GO_PR_EXT ant acid p',
#   'CHEBI_PR_EXT TRAP',
#   'CHEBI_SO_EXT marker',
#   'CL osteoclasos',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT +',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'PR_EXT ALP',
#   'PR_EXT TRAP',
#   'CL_GO_EXT cells',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT +',
#   'NCBITaxon mice',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'CL osteoboste',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT +',
#   'NCBITaxon mice',
#   'GO osteoblast',
#   'UBERON bbone',
#   'UBERON bone',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT +',
#   'NCBITaxon mice',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT +',
#   'NCBITaxon mice',
#   'CHEBI_UBERON_EXT fat',
#   'CL osteoblasts',
#   'CL osteoclasts',
#   'UBERON tissue',
#   'PR_EXT Sam6S',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'CHEBI_UBERON_EXT fat',
#   'NCBITaxon mice',
#   'SO_EXT genotype',
#   'CL_GO_EXT cells',
#   'GO expressed',
#   'UBERON bone',
#   'CL osteoblasts',
#   'CL osteoclasts',
#   'NCBITaxon mice',
#   'UBERON serum',
#   'CHEBI_SO_EXT C-telopeptide',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'CHEBI_EXT estrogen',
#   'NCBITaxon mice',
#   'SO_EXT ggenotyp',
#   'PR_EXT interleukin-6',
#   'CHEBI_PR_EXT leptin',
#   'GO regulating',
#   'UBERON_EXT body',
#   'UBERON_EXT bone',
#   'UBERON serum',
#   'CHEBI leptin',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT +',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mimi',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT +',
#   'NCBITaxon mice',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'UBERON_EXT bone',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'CHEBI_EXT estrogen',
#   'CHEBI_PR_EXT leptin',
#   'CL Osteoblast',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon Mice',
#   'UBERON_EXT bone',
#   'UBERON adult',
#   'CL osteoblast',
#   'UBERON_EXT bone',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'UBERON_EXT bone',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'CL osteobosteo',
#   'CL osteoclasts',
#   'UBERON bobone marr',
#   'CL_GO_EXT cells',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'CL osteoblast',
#   'GO_RO_EXT differentiation',
#   'PR_EXT ALP',
#   'CHEBI nodules',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT +',
#   'NCBITaxon mice',
#   'CL fibroblast',
#   'GO_EXT RT',
#   'CHEBI_EXT molecular',
#   'CHEBI_SO_EXT markers',
#   'CL osteoblast',
#   'GO_RO_EXT differentiation',
#   'CHEBI_SO_EXT RNA',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT +',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'CHEBI_PR_EXT collagen',
#   'GO_EXT up-regulated',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'CL osteoclasts',
#   'GO_EXT re',
#   'UBERON bones',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT +',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'PR_EXT TRAP',
#   'CHEBI electron',
#   'CL osteoclasts',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'PR_EXT Src',
#   'SO_EXT null',
#   'NCBITaxon mice',
#   'PR_EXT Sam68',
#   'CL Adipocyte',
#   'GO_RO_EXT Differentiation',
#   'CL Osteoblast',
#   'GO_RO_EXT DiffDifferentia',
#   'UBERON_EXT bone',
#   'CL_GO_EXT cellc',
#   'CL osteoblasts',
#   'CL adipocytes',
#   'UBERON bone',
#   'GO_RO_EXT differentiation',
#   'CL adipocyte',
#   'PR_EXT Sam68',
#   'UBERON bone marrow',
#   'CL_GO_EXT cells',
#   'GO_RO_EXT differentiate',
#   'GO osteogenic',
#   'PR_EXT Sam68',
#   'GO regulate',
#   'UBERON_EXT bone',
#   'CHEBI neuroendocrine',
#   'CHEBI_PR_EXT leptin',
#   'UBERON sympathetic nervous',
#   'GO_EXT negatively',
#   'PR_EXT Sam68',
#   'GO regregulat',
#   'CL adipocyte',
#   'GO_RO_EXT differentiation',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT +',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'UBERON embryos',
#   'PR_EXT Sam6S',
#   'SO_EXT −',
#   'SO_EXT −',
#   'GO_PATO_RO_EXT differentiated',
#   'CL adipocytes',
#   'CHEBI pioglitazone',
#   'GO adipogenesis',
#   'CL_GO_EXT CeCel',
#   'GO adipogenesis',
#   'GO Adipogenesis',
#   'SO_EXT wild-tywi',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'PR_EXT Sam68',
#   'CL adipocyte',
#   'GO_RO_EXT differentiation',
#   'GO expression',
#   'GO_EXT transcription factors',
#   'PR_EXT PPARγ',
#   'PR_EXT KLF5',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'GO_PATO_RO_EXT differe',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT +',
#   'GO adi',
#   'PR_EXT Sam68',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'PR_EXT SaSam',
#   'GO differentiation of ',
#   'CL mesenchymal ',
#   'CL_GO_EXT cells',
#   'CL_GO_EXT cell',
#   'UBERON embryonic mesenchymal',
#   'GO cells C3H10',
#   'PR_EXT BMP-2',
#   'CL osteoblast',
#   'GO_RO_EXT differentiation',
#   'GO expression',
#   'PR_EXT osteocalcin',
#   'SO_EXT gene',
#   'CL_GO_EXT cecel',
#   'GO transfected',
#   'PR_EXT Sam68',
#   'CHEBI puromycin',
#   'GO expression',
#   'PR_EXT Sam68',
#   'PR_EXT β-β-act',
#   'CL Osteoblast',
#   'GO_RO_EXT differentiatife',
#   'GO expressing',
#   'PR_EXT Sam68',
#   'PR_EXT BMP-2',
#   'GO expexpress',
#   'PR_EXT OCN',
#   'PR_EXT β-actin',
#   'CHEBI_SO_EXT mRNAs',
#   'GO_EXT RT',
#   'PR_EXT Sam68sh',
#   'GO expressing',
#   'CL_GO_EXT cells',
#   'CL osteoblast',
#   'CL_GO_EXT cells',
#   'GO expression',
#   'GO nodule formation',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'UBERON bone',
#   'CL_GO_EXT cells',
#   'CHEBI hairp',
#   'CHEBI_SO_EXT RNA',
#   'SO_EXT shRNA',
#   'UBERON_EXT bone',
#   'NCBITaxon mice',
#   'UBERON_EXT bone',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT +',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'UBERON tissue',
#   'CL adipocytes',
#   'CHEBI_SO_EXT labeling',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT +',
#   'NCBITaxon mice',
#   'UBERON trabecular bone',
#   'CHEBI fluorochrome',
#   'UBERON bones',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'NCBITaxon mice',
#   'SO_EXT genotype',
#   'PR_EXT Sam68',
#   'GO_EXT regulates',
#   'GO_RO_EXT differentiatioe',
#   'CL bone marrow mesenchymal ',
#   'CL_GO_EXT cells',
#   'CL adipocyte',
#   'GO_RO_EXT differendiffere',
#   'CL osteoblast',
#   'GO_RO_EXT differentiation',
#   'GO aging bone',
#   'GO_PATO_EXT physiologip',
#   'PR_EXT Sam68',
#   'GO modulate',
#   'UBERON bone marrow',
#   'CL mesenchymal stem ',
#   'CL_GO_EXT cellc',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'UBERON_EXT bone',
#   'SO_EXT wild-type',
#   'GO_PATO_EXT ged',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT +',
#   'SO_EXT wild-type',
#   'UBERON bone',
#   'NCBITaxon mammals',
#   'PR_EXT SamSa',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon animals',
#   'UBERON_EXT bone',
#   'GO_RO_EXT differendiffere',
#   'CL bone marrow stem ',
#   'CL_GO_EXT cells',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'UBERON embryonic mesenchymal',
#   'CL_GO_EXT cells',
#   'PR_EXT Sam68',
#   'SO_EXT shRNA',
#   'CL teoblost',
#   'GO_RO_EXT differentiation',
#   'PR_EXT Sam68',
#   'CL osteoblast',
#   'GO_RO_EXT differentiation',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon animals',
#   'CL adipocyte',
#   'GO_RO_EXT differentiation',
#   'PR_EXT Sam68',
#   'SO_EXT +',
#   'SO_EXT +',
#   'GO_PATO_EXT physiologic',
#   'PR_EXT Sam68',
#   'GO regulate',
#   'CHEBI_EXT adipogenic',
#   'GO osteoosteo',
#   'GO_RO_EXT differentiation',
#   'UBERON bone marrow mesenchymal',
#   'PR_EXT Sam68',
#   'CHEBI_PR_EXT proprot',
#   'GO expression',
#   'NCBITaxon mouse',
#   'UBERON embemb',
#   'PR_EXT Sam68',
#   'CHEBI_SO_EXT mRNA',
#   'GO expressed',
#   'PR_EXT Sam68',
#   'UBERON brain',
#   'UBERON heart',
#   'UBERON intestine',
#   'UBERON liver',
#   'UBERON_EXT skin',
#   'UBERON kidney',
#   'UBERON embryos',
#   'GO expression',
#   'PR_EXT Sam68',
#   'CL neurons',
#   'UBERON intestinal',
#   'GO expression',
#   'PR_EXT Sam68',
#   'GO aging',
#   'CL_GO_EXT cells',
#   'CL_GO_EXT cells',
#   'PR_EXT Sam68',
#   'CL chondrocytch',
#   'CL osteoblasts',
#   'CL osteoclasts',
#   'UBERON cartilage',
#   'UBERON_EXT bone',
#   'CHEBI_PR_EXT protein',
#   'GO skeletal developmen',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   'SO_EXT −',
#   'NCBITaxon mice',
#   'SO_EXT domain',
#   'SO_EXT deleted',
#   'PR_EXT Sam68',
#   'SO_EXT −',
#   ...],
#  '12585968': ['SO_EXT null',
#   'SO_EXT mutant',
#   'NCBITaxon mice',
#   'UBERON ear',
#   'GO_UBERON_EXT innervation',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'CHEBI_EXT molecular',
#   'CHEBI_SO_EXT markers',
#   'GO apoptosis',
#   'PATO_UBERON_EXT neonaneo',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'PR_EXT neurotrophin',
#   'GO expression',
#   'GO_EXT sensory',
#   'CL  neurons',
#   'UBERON embr',
#   'GO embryonic develop',
#   'SO_EXT mutanmu',
#   'GO_UBERON_EXT innervation',
#   'GO expression',
#   'PR_EXT neurotneurotr',
#   'GO birth',
#   'GO expression',
#   'PR_EXT BDNB',
#   'PR_EXT NT-3',
#   'SO_EXT mutant',
#   'UBERON sensory epithelia',
#   'CHEBI DiI',
#   'PR_EXT neurotrophin',
#   'SO_EXT null',
#   'SO_EXT mutations',
#   'GO natal',
#   'GO_UBERON_EXT innervnnerv',
#   'PR_EXT myosin VIIa',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'SO_EXT mutant',
#   'UBERON cochlea',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'SO_EXT mutant',
#   'UBERON_EXT vestibular',
#   'UBERON sensory epithelia',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'UBERON cochlea',
#   'GO_EXT sensory',
#   'CL neurons',
#   'UBERON vestibular epithelia',
#   'SO_EXT mutant',
#   'NCBITaxon mice',
#   'UBERON_EXT vestibular',
#   'UBERON sensory epithelia',
#   'UBERON cochlear',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'UBERON cochlea',
#   'GO projections',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'GO expressiex',
#   'PR_EXT neurotrophins',
#   'UBERON cochlea',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'NCBITaxon mice',
#   'CL support ma',
#   'GO_EXT sensory',
#   'CL neurons',
#   'UBERON cochlea',
#   'GO birth',
#   'CHEBI_EXT molecular',
#   'CL apical spiral neu',
#   'UBERON Keywords',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'GO_UBERON_EXT innervation',
#   'GO_UBERON_EXT innervation',
#   'PR_EXT Brn3c',
#   'SO_EXT domain',
#   'UBERON inner ear',
#   'CL hair ',
#   'CL_GO_EXT cell',
#   'GO  development',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutamut',
#   'GO express',
#   'CL_GO_EXT cellular',
#   'CHEBI_SO_EXT markers',
#   'PR_EXT Myosin VI and VIIa',
#   'CHEBI_PR_EXT calcalreti',
#   'PR_EXT parvalbumin',
#   'CL hair ',
#   'CL_GO_EXT cecel',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'GO apoptosis',
#   'PATO_UBERON_EXT neonates',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'UBERON_EXT vestibular',
#   'CL spiral ganglion ',
#   'CL_GO_EXT cells',
#   'GO natal',
#   'UBERON_EXT v',
#   'UBERON vestibula',
#   'CL neurons',
#   'UBERON spiral',
#   'CL  neurons',
#   'UBERON adults',
#   'GO_UBERON_EXT innervation',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mmutant',
#   'GO_RO_EXT differentiation',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'PR_EXT Brn3c',
#   'SO_EXT mutants',
#   'PR_EXT neurotroneur',
#   'GO expression',
#   'CL_GO_EXT cells',
#   'GO_EXT sensory',
#   'CL neurons',
#   'GO embryonic development',
#   'PR_EXT neurotrophin',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'PR_EXT neurotrophin',
#   'GO_EXT sensory',
#   'CL  neurons',
#   'UBERON embryonic',
#   'UBERON ear',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'PR_EXT neurotrophin',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'UBERON embryos',
#   'PR_EXT NT-3',
#   'GO expressed',
#   'CL supportinsu',
#   'CL_GO_EXT cells',
#   'GO birth',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'UBERON_EXT vestibular',
#   'GO_EXT senso',
#   'CL lear senso',
#   'PR_EXT NT-3',
#   'GO expression',
#   'GO_EXT downregulated',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'GO_RO_EXT differentiation',
#   'GO  of ',
#   'CL supporting ',
#   'CL_GO_EXT cellc',
#   'PR_EXT neurotroneuro',
#   'GO_EXT downregulated',
#   'NCBITaxon postnatal mammals',
#   'SO_EXT replaced',
#   'GO_UBERON_EXT innervation',
#   'PR_EXT Brn3c',
#   'SO_EXT mutants',
#   'GO expression',
#   'PR_EXT NT-3',
#   'PR_EXT BDNF',
#   'CL sensory neuron',
#   'PR_EXT neurotrophin',
#   'CL hair ',
#   'CL_GO_EXT ccell',
#   'GO birth',
#   'NCBITaxon animals',
#   'NCBITaxon human',
#   'PR_EXT Pou4f3',
#   'SO_EXT gene',
#   'PR_EXT DFNA15',
#   'UBERON cochlear',
#   'GO_EXT sensory',
#   'CL neurons',
#   'UBERON cochlear',
#   'SO_EXT null',
#   'SO_EXT mutant',
#   'NCBITaxon mice',
#   'CL hair ',
#   'GO cell diff',
#   'GO_RO_EXT differentia',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'GO natal',
#   'UBERON cochlea',
#   'UBERON spiral',
#   'CL  neurons',
#   'PR_EXT neurotrophins',
#   'GO expression',
#   'PATO_UBERON_EXT neonatal',
#   'NCBITaxon rodents',
#   'SO_EXT null',
#   'SO_EXT mutation',
#   'UBERON inner ear',
#   'GO_UBERON_EXT innervation',
#   'PR_EXT BDNF',
#   'PR_EXT NT-3',
#   'SO_EXT null',
#   'SO_EXT mutations',
#   'GO birth',
#   'SO_EXT mutanmu',
#   'PR_EXT BDNF',
#   'GO_EXT receptor',
#   'PR_EXT trkB',
#   'SO_EXT inner',
#   'GO vation',
#   'UBERON semisemicircular ca',
#   'GO_UBERON_EXT nervation',
#   'UBERON utricle',
#   'UBERON ssaccul',
#   'UBERON cochlea',
#   'SO_EXT null',
#   'SO_EXT mutatiomu',
#   'PR_EXT NT-3',
#   'GO_EXT receptor',
#   'PR_EXT trkC',
#   'CL spiral spiral ',
#   'GO spiral',
#   'UBERON tip',
#   'SO_EXT null',
#   'SO_EXT null',
#   'NCBITaxon mice',
#   'PR_EXT neurotrophins',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'GO birth',
#   'UBERON Vestibular ganglia',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutanmu',
#   'PR_EXT BDNF',
#   'PR_EXT trkB',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'UBERON vestibular ganglia',
#   'UBERON vestibular',
#   'GO_EXT sensory',
#   'CL  neurons',
#   'PR_EXT BDNF',
#   'PR_EXT trkB',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'UBERON vestibular',
#   'GO_EXT sensory',
#   'CL  neuneur',
#   'UBERON Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'UBERON_EXT vestibular',
#   'GO_EXT sensory',
#   'GO ganglion',
#   'GO_EXT BDNF production',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'UBERON vestibular ganglia',
#   'SO_EXT mutant',
#   'CHEBI_SO_EXT labeled',
#   'CHEBI DiI',
#   'PATO_UBERON_EXT newborn',
#   'NCBITaxon animals',
#   'UBERON vestibular ganglion',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'UBERON crista',
#   'UBERON ggl',
#   'UBERON ganglion',
#   'UBERON c',
#   'UBERON spiral capillary',
#   'UBERON Geni',
#   'SO_EXT G',
#   'UBERON ulate ganglion',
#   'UBERON epithelial',
#   'UBERON crista',
#   'CL HaC',
#   'CL vestibular hair ',
#   'CL_GO_EXT cell',
#   'CL inner hair ',
#   'CL_GO_EXT ccel',
#   'CL hair ',
#   'CL_GO_EXT cell',
#   'UBERON ganglionic spiral bundli',
#   'CL OHC',
#   'CL outer hair ',
#   'CL_GO_EXT cell',
#   'UBERON PC',
#   'UBERON crista',
#   'UBERON saccule',
#   'UBERON spiral ganglio',
#   'UBERON TM',
#   'UBERON tectorial membrane',
#   'UBERON cochlear',
#   'GO nucleus',
#   'UBERON VG',
#   'UBERON_EXT vestibular',
#   'UBERON ganglion',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'UBERON_EXT vestibular',
#   'UBERON sensory epitheory',
#   'GO_UBERON_EXT inneinnerva',
#   'PR_EXT BDNF',
#   'PR_EXT trkB',
#   'SO_EXT null',
#   'SO_EXT mutations',
#   'UBERON sensory epitheliue',
#   'GO_UBERON_EXT innervation',
#   'GO_UBERON_EXT innervation',
#   'UBERON utricle',
#   'UBERON saccule',
#   'PR_EXT BDNF',
#   'SO_EXT null',
#   'SO_EXT mutant',
#   'NCBITaxon mice',
#   'UBERON saccule',
#   'SO_EXT null',
#   'NCBITaxon mice',
#   'GO_UBERON_EXT innervation',
#   'MOP acteylated',
#   'PR_EXT tubulin',
#   'GO_UBERON_EXT Innervation',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'UBERON ears',
#   'PATO_UBERON_EXT newborn',
#   'NCBITaxon mice',
#   'UBERON vestibular endorgan',
#   'CHEBI DiI',
#   'CHEBI_SO_EXT labeling',
#   'MOP acetylated',
#   'PR_EXT tubulin',
#   'UBERON cochlea',
#   'UBERON Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'CL outer hair ',
#   'CL_GO_EXT cells',
#   'UBERON ganglionic spiral',
#   'CL spiral sensory neurons',
#   'PR_EXT P4',
#   'GO_UBERON_EXT innervation',
#   'UBERON coccoch',
#   'UBERON Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'CL spiral neurons',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'PR_EXT NT-3',
#   'PR_EXT trkC',
#   'GO_UBERON_EXT nnervation',
#   'GO_UBERON_EXT innervation',
#   'NCBITaxon animaan',
#   'PR_EXT BDNF',
#   'GO expressed',
#   'GO_UBERON_EXT innervatio',
#   'PR_EXT neurotrophin',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'CL spiral sensory nneuron',
#   'UBERON efferents',
#   'PR_EXT BDNF',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'PR_EXT neurotrophin',
#   'SO_EXT null',
#   'SO_EXT mutant',
#   'CL outer hair ',
#   'CL_GO_EXT cells',
#   'SO_EXT wildtype',
#   'UBERON efferent',
#   'CL outer outer',
#   'CL_GO_EXT cells',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'CL hair ',
#   'CL_GO_EXT cell',
#   'CL outer hair ',
#   'CL_GO_EXT cell',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutant',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutamut',
#   'UBERON_EXT vestibular',
#   'GO_UBERON_EXT innervation',
#   'UBERON effer',
#   'UBERON utricle',
#   'UBERON sacculs',
#   'GO_UBERON_EXT innervation',
#   'UBERON crcrist',
#   'UBERON horiz',
#   'UBERON canal',
#   'GO_UBERON_EXT innervation',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'GO_UBERON_EXT ininnervati',
#   'UBERON ear',
#   'NCBITaxon mice',
#   'UBERON_EXT vestivesti',
#   'UBERON sensory epithelia',
#   'GO_UBERON_EXT innervation',
#   'UBERON efferent',
#   'UBERON utricle',
#   'UBERON cochlea',
#   'GO spiral',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'SO_EXT mutant',
#   'CL outer hair ',
#   'CL_GO_EXT cells',
#   'UBERON inner spiral bundles',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'CHEBI DiI',
#   'MOP acetylated',
#   'PR_EXT tubulin',
#   'UBERON cochlec',
#   'GO_UBERON_EXT innervation',
#   'CL outer hair ',
#   'CL_GO_EXT cellc',
#   'GO_UBERON_EXT innervation',
#   'CL outer hair ',
#   'CL_GO_EXT cell',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'NCBITaxon animals',
#   'GO innervation',
#   'CL inner hair ',
#   'CL_GO_EXT ccell',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'UBERON habenula',
#   'CL hair ',
#   'CL_GO_EXT cell',
#   'UBERON inner spiral',
#   'UBERON f',
#   'UBERON habenula',
#   'UBERON perfor',
#   'PATO_UBERON_EXT newborn',
#   'NCBITaxon animals',
#   'GO_UBERON_EXT innervation',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutmutati',
#   'UBERON Brn3c',
#   'SO_EXT nuln',
#   'SO_EXT mutant',
#   'UBERON hist',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'UBERON cochlea',
#   'CL hair ',
#   'CL_GO_EXT cell',
#   'UBERON apex of the cochlea',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'UBERON vestibular endorgans',
#   'UBERON vestibular end organs',
#   'CL hair ',
#   'CL_GO_EXT celce',
#   'UBERON sensory epithelium',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'UBERON habenula',
#   'CL spiral sensory neurons',
#   'UBERON Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'UBERON cochcoc',
#   'UBERON spiral capillaca',
#   'UBERON organ of Corti',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'CL pillar ',
#   'CL_GO_EXT cells',
#   'GO_PATO_RO_EXT differentiated',
#   'UBERON cochlea',
#   'UBERON Deiters',
#   'CL_GO_EXT cells',
#   'CHEBI_EXT molecular',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'CL supsupporti',
#   'CL_GO_EXT cells',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'UBERON cochlea',
#   'GO cytologicyt',
#   'GO_RO_EXT differentiation',
#   'PR_EXT Brn',
#   'SO_EXT mutant',
#   'UBERON cochleae',
#   'GO antibody',
#   'CL outer hair ',
#   'CL_GO_EXT cells',
#   'CL inner hair ',
#   'CL_GO_EXT cells',
#   'SO_EXT wildtype',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'SO_EXT mutant',
#   'CL_GO_EXT cell',
#   'UBERON middle',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'GO_RO_EXT differentiation',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'PR_EXT tubulin',
#   'UBERON capillary',
#   'UBERON of Corti',
#   'CL inner and outer hair ',
#   'CL_GO_EXT cells',
#   'SO_EXT wildtype',
#   'UBERON organorgan of ',
#   'SO_EXT mutants',
#   'UBERON tunnel of Corti',
#   'GO cyotological',
#   'GO_RO_EXT differentiation',
#   'PR_EXT tubulin',
#   'CL_GO_EXT cells',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'CL sensory  neuron',
#   'SO_EXT wildtype',
#   'SO_EXT mutant',
#   'SO_EXT wildtype',
#   'SO_EXT mutants',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'UBERON vestibular',
#   'UBERON colar an',
#   'GO vestibular',
#   'UBERON cochlear',
#   'GO_EXT sensory',
#   'CL neurons',
#   'GO_PATO_RO_EXT differentiated',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'UBERON cochlea',
#   'UBERON cochlear',
#   'GO_EXT sensory',
#   'CL neurons',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'GO_RO_EXT dif',
#   'GO_PATO_RO_EXT differentia',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'GO_EXT sensory',
#   'CL  neurons',
#   'CL hair ',
#   'CL_GO_EXT cellc',
#   'SO_EXT wildtype',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutant',
#   'UBERON cochlear',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'CL spiral sensory neurons',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'UBERON_EXT vestibular',
#   'UBERON sensory epithelia',
#   'UBERON saccule',
#   'UBERON_EXT vestibular',
#   'GO_EXT ssensor',
#   'CL  neurons',
#   'GO projection',
#   'CHEBI DiI',
#   'CHEBI DiA',
#   'UBERON cochlear',
#   'GO nuclei',
#   'UBERON cochlear nerve',
#   'UBERON ventral cochlear',
#   'GO nucleus',
#   'GO projections',
#   'SO_EXT wildtype',
#   'GO pprojectio',
#   'GO nuclei',
#   'NCBITaxon mice',
#   'GO audit',
#   'CL hair ',
#   'CL_GO_EXT cell',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutant',
#   'NCBITaxon mouse',
#   'UBERON bas',
#   'UBERON cochlear nerve',
#   'UBERON ventral cochlear',
#   'GO nucleus',
#   'GO_EXT signaling',
#   'CL hair ',
#   'CL_GO_EXT celce',
#   'UBERON cochlea',
#   'PR_EXT Brn',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'UBERON vestibular epithelia',
#   'GO_UBERON_EXT innervation',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'UBERON vestibular',
#   'GO_EXT sensory neurons',
#   'UBERON canal eepitheli',
#   'UBERON horizontal canal',
#   'UBERON utricle',
#   'UBERON saccule',
#   'UBERON epithelia',
#   'NCBITaxon mice',
#   'GO trans',
#   'CL_GO_EXT cellular',
#   'CHEBI_SO_EXT labeling',
#   'CL_GO_EXT cells',
#   'UBERON Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutant',
#   'UBERON utricle',
#   'CL_GO_EXT cells',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'GO_UBERON_EXT nervinner',
#   'UBERON sensory epithelia',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mumuta',
#   'NCBITaxon mice',
#   'NCBITaxon animals',
#   'UBERON_EXT vestibular',
#   'UBERON sensory epithelia',
#   'UBERON sensory epithelia',
#   'GO Trans',
#   'CL_GO_EXT cellular',
#   'CHEBI_SO_EXT labeling',
#   'CHEBI DiI',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'UBERON cochlea',
#   'CL spiral ',
#   'GO_EXT sensory',
#   'CL  neurneu',
#   'UBERON organ of Corti',
#   'UBERON epithelium',
#   'UBERON cochlea',
#   'UBERON spiral bundle',
#   'GO_EXT myelinated',
#   'GO spiral',
#   'CL outer outer',
#   'CL_GO_EXT cells',
#   'GO_PATO_EXT maturation',
#   'CL neurons',
#   'CL hair ',
#   'CL_GO_EXT ccell',
#   'UBERON cochlea',
#   'GO_UBERON_EXT innervation',
#   'PR_EXT neurotrophin',
#   'PR_EXT neurotroph',
#   'GO_EXT neurotrophi',
#   'SO_EXT null',
#   'SO_EXT mutations',
#   'SO_EXT mutant',
#   'NCBITaxon mice',
#   'GO birth',
#   'GO hybridization',
#   'PATO_UBERON_EXT neonatal',
#   'PR_EXT neurotrophin',
#   'GO expression',
#   'UBERON Brn3c',
#   'SO_EXT null',
#   'GO expression',
#   'PR_EXT BDNF',
#   'PR_EXT NT-3',
#   'CHEBI_SO_EXT ribribopro',
#   'PR_EXT neurotrophie',
#   'GO expression',
#   'NCBITaxon animals',
#   'PR_EXT neurotrophins',
#   'GO_EXT downregdownre',
#   'PATO_UBERON_EXT neonates',
#   'GO expression',
#   'NCBITaxon animals',
#   'UBERON cristae',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'NCBITaxon animals',
#   'SO_EXT null',
#   'SO_EXT mutant',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'GO BDNF signal',
#   'UBERON utricle',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'NCBITaxon animal',
#   'GO silver',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'GO expression',
#   'PR_EXT BDNF',
#   'PR_EXT NT-3',
#   'CHEBI_SO_EXT mRNA',
#   'UBERON_EXT vestibular',
#   'UBERON sensory epithelia',
#   'UBERON cristae',
#   'UBERON saccule',
#   'UBERON utricle',
#   'PR_EXT BDNF',
#   'PR_EXT NT-3',
#   'PR_EXT BDNF',
#   'GO expression',
#   'CL hair ',
#   'CL_GO_EXT cell',
#   'UBERON canal',
#   'UBERON saccule',
#   'GO expression',
#   'SO_EXT null',
#   'NCBITaxon mice',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'PR_EXT NT-3',
#   'GO expression',
#   'SO_EXT mutant',
#   'UBERON saccule',
#   'PR_EXT BDNF',
#   'PR_EXT NT-3',
#   'UBERON Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutant',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'NCBITaxon animals',
#   'CL hair ',
#   'CL_GO_EXT cell',
#   'PR_EXT Brn3c',
#   'SO_EXT nnul',
#   'SO_EXT mutants',
#   'PR_EXT NT-3',
#   'SO_EXT null',
#   'UBERON sensory epithelium',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutant',
#   'UBERON cochlea',
#   'SO_EXT nunu',
#   'PR_EXT NT-3',
#   'UBERON organ of Corti',
#   'SO_EXT null',
#   'PR_EXT NT-3',
#   'UBERON cochlea',
#   'SO_EXT null',
#   'NCBITaxon mice',
#   'PR_EXT BDNF',
#   'PR_EXT NT-3',
#   'CHEBI_SO_EXT mRNA',
#   'GO expression',
#   'UBERON cochlea',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'GO expression',
#   'PR_EXT BDNF',
#   'SO_EXT wildtype',
#   'SO_EXT mumuta',
#   'GO expression',
#   'PR_EXT NT-3',
#   'CL inner hair ',
#   'CL_GO_EXT cells',
#   'SO_EXT wildwild',
#   'PR_EXT NT-3',
#   'GO expression',
#   'SO_EXT null',
#   'NCBITaxon mice',
#   'CL inner hair ',
#   'CL_GO_EXT cells',
#   'NCBITaxon animals',
#   'GO expression',
#   'PR_EXT neurotrophins',
#   'CL primary neuronn',
#   'GO apical',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'PR_EXT neurotrophins',
#   'GO apical',
#   'CL spiral neurons',
#   'GO_PATO_RO_EXT differentiatff',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'SO_EXT mutant',
#   'NCBITaxon animals',
#   'NCBITaxon_UBERON_EXT childrec',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'GO expression',
#   'PR_EXT neurotrophins',
#   'SO_EXT rescue',
#   'PR_EXT neurotrophins',
#   'GO cell death',
#   'GO regregulat',
#   'CL neuronal',
#   'GO_EXT neurotrophic',
#   'PR_EXT neurotrophins',
#   'GO_EXT released',
#   'GO_EXT sensory',
#   'CL  neurneu',
#   'PR_EXT neurotrophneu',
#   'PR_EXT neurotrneurot',
#   'NCBITaxon animals',
#   'GO_EXT sensory',
#   'CL  neurons',
#   'GO_UBERON_EXT innervation',
#   'PR_EXT neurotrophin',
#   'GO_EXT neurotrophin receptor',
#   'SO_EXT null',
#   'SO_EXT mutamut',
#   'GO expression',
#   'UBERON brain',
#   'UBERON embryos',
#   'PR_EXT Brn3c',
#   'GO expressed',
#   'GO embembryogene',
#   'UBERON CNS',
#   'CL neurons',
#   'GO expression',
#   'PR_EXT neurotrophins',
#   'CL primary neurons',
#   'PATO_UBERON_EXT newborn',
#   'GO natal',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'NCBITaxon mice',
#   'GO expression',
#   'PR_EXT BDNF',
#   'CHEBI_GO_EXT biologically',
#   'PR_EXT neurotrophins',
#   'GO expressed',
#   'UBERON sensory epithelia',
#   'UBERON embryonic',
#   'UBERON Brbry',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'PR_EXT neuroneurotro',
#   'UBERON_EXT vestibular',
#   'UBERON sensory epithelia',
#   'PR_EXT NT-3',
#   'GO expression',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutant',
#   'UBERON cochlea',
#   'PR_EXT neurotrophin',
#   'CL spiral sensory neurons',
#   'GO_UBERON_EXT innervation',
#   'PATO_UBERON_EXT newborn',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'GO_RO_EXT differentiation',
#   'CL haiha',
#   'CL_GO_EXT cells',
#   'GO expression',
#   'PR_EXT BDNF',
#   'UBERON cristae',
#   'PR_EXT BDNF',
#   'PR_EXT trkB',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'GO_UBERON_EXT nervation',
#   'UBERON cristae',
#   'GO birth',
#   'GO expression',
#   'UBERON sensory epithelia',
#   'GO_UBERON_EXT innervation',
#   'UBERON efferents',
#   'GO birth',
#   'UBERON utricle',
#   'UBERON saccule',
#   'UBERON cochlea',
#   'PR_EXT BBDN',
#   'PR_EXT NT-3',
#   'GO expressed',
#   'PR_EXT NT-3',
#   'GO expression',
#   'UBERON apex of the cochlea',
#   'UBERON cochlea of embryos',
#   'PATO_UBERON_EXT neoneona',
#   'UBERON saccule',
#   'UBERON utricle',
#   'UBERON embryos',
#   'PR_EXT NT-3',
#   'GO expressed',
#   'CL supporting ',
#   'CL_GO_EXT cells',
#   'GO expression',
#   'PR_EXT NT-3',
#   'CL supporting ',
#   'CL_GO_EXT cells',
#   'UBERON embryos',
#   'PATO_UBERON_EXT neonates',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'GO_EXT sensory',
#   'CL  neurons',
#   'NCBITaxon animals',
#   'GO apical',
#   'GO_EXT sensory',
#   'CL  neurons',
#   'GO_PATO_RO_EXT differentiated',
#   'CL haiha',
#   'CL_GO_EXT cells',
#   'PR_EXT neurotrophins',
#   'PR_EXT BDNF',
#   'PR_EXT NT-3',
#   'GO expression',
#   'CL inner hair ',
#   'CL_GO_EXT cells',
#   'GO birth',
#   'UBERON ear',
#   'UBERON nervous system',
#   'PR_EXT neurotrophins',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'CL spiral neuron',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'GO_EXT released',
#   'GO_PATO_RO_EXT differentiated',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'GO expression',
#   'GO_EXT n',
#   'PR_EXT neurotrophin',
#   'GO_PATO_RO_EXT differentiated',
#   'UBERON epithelia',
#   'PR_EXT neurotrophins',
#   'UBERON adult',
#   'UBERON cochldul',
#   'PR_EXT neurotrophin',
#   'GO expression',
#   'GO natal',
#   'NCBITaxon animals',
#   'UBERON CNS',
#   'GO expexpress',
#   'UBERON CNS',
#   'PR_EXT neutrop',
#   'CL hins',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'CL primary neurons',
#   'GO birth',
#   'PR_EXT Brn3c',
#   'SO_EXT null',
#   'SO_EXT mutants',
#   'GO_EXT nneurotrophi',
#   'UBERON CNS',
#   'CL spiral sensory neurons',
#   'NCBITaxon humans',
#   'GO_EXT Growth',
#   'UBERON cochlea',
#   'CL hair ',
#   'CL_GO_EXT cells',
#   'CL spiral neurons',
#   'UBERON organ of Corti',
#   ...],
#  '17201918': ['GO modulates',
#   'PR_EXT estrogen–insulin-like ',
#   'GO_EXT growth factor',
#   'PR_EXT -1',
#   'GO_EXT signal',
#   'GO r-1',
#   'GO natal development of ',
#   'UBERON mammary gland',
#   'NCBITaxon mice',
#   'PR_EXT Estrogen and insulin-like ',
#   'GO_EXT growth factor',
#   'PR_EXT -1',
#   'PR_EXT IGF-1',
#   'GO mammary gland development',
#   'PR_EXT SirT1',
#   'SO_EXT conserved',
#   'GO_EXT protein deacetylase',
#   'GO regulate',
#   'PR_EXT insulin',
#   'PR_EXT IGF-1',
#   'GO_EXT signaling',
#   'NCBITaxon organisms',
#   'GO_EXT transcription factors',
#   'GO NF-κB',
#   'NCBITaxon mammalian',
#   'CL_GO_EXT cells',
#   'PR_EXT SirT1',
#   'GO regulates',
#   'PR_EXT IGF-1',
#   'GO_EXT signaling',
#   'GO mammary gland development',
#   'PR_EXT SirT1',
#   'PR_EXT SirT1',
#   'NCBITaxon mice',
#   'PR_EXT SirT1',
#   'NCBITaxon mice',
#   'NCBITaxon mice',
#   'SO_EXT mutation',
#   'PR_EXT SirT1',
#   'SO_EXT gene',
#   'PR_EXT SirT1',
#   'PR_EXT CMV',
#   'SO_EXT transgenic',
#   'NCBITaxon mice',
#   'GO mammary gland development in',
#   'SO_EXT pregnant',
#   'NCBITaxon mice',
#   'CHEBI_EXT estrogen',
#   'GO implantation',
#   'UBERON capular',
#   'PATO_UBERON_EXT male',
#   'PATO_UBERON_EXT female',
#   'NCBITaxon mice',
#   'GO_EXT growth',
#   'NCBITaxon mice',
#   'GO morphogmorpho',
#   'PR_EXT SirT1',
#   'NCBITaxon mice',
#   'GO implantation',
#   'SO_EXT rescue',
#   'GO morphogenesis',
#   'CHEBI_EXT estrogen',
#   'PR_EXT IGF-1',
#   'CHEMINF_GO_EXT bindibi',
#   'CHEBI_PR_EXT protein',
#   'PR_EXT -1',
#   'GO expression',
#   'PR_EXT SirT1',
#   'UBERON tissues',
#   'PR_EXT IκBα',
#   'GO expression',
#   'CHEBI_EXT estr',
#   'PR_EXT IGF-1',
#   'SO_EXT rescued',
#   'GO mmorphogenesi',
#   'PR_EXT TNFα',
#   'PR_EXT IκBα',
#   'CL_GO_EXT cells',
#   'GO cellular response',
#   'GO modulates',
#   'PR_EXT IGF-1',
#   'GO_EXT signaling',
#   'GO_EXT growth',
#   'GO regulation',
#   'GO mammary gland development',
#   'NCBITaxon mmic',
#   'GO deregulates',
#   'GO expression',
#   'PR_EXT IGF-1',
#   'CHEMINF_GO_EXT bindinb',
#   'CHEBI_PR_EXT protein',
#   'PR_EXT -1',
#   'PR_EXT IGF-1',
#   'CHEBI estrogen',
#   'PR_EXT IGF-1',
#   'GO_EXT signaling',
#   'GO_EXT duc',
#   'GO morphogenesis',
#   'CHEBI_GO_SO_EXT enzymatic',
#   'PR_EXT SirT1',
#   'GO_EXT growth',
#   'GO malignant',
#   'GO_EXT grlign',
#   'CL mammary epithelial ',
#   'CL_GO_EXT cells',
#   'NCBITaxon Mammalian',
#   'PR_EXT SirT1',
#   'CHEBI_GO_EXT nicoti',
#   'CHEBI_SO_EXT aden',
#   'CHEBI_SO_EXT dinucleotide',
#   'GO_EXT histone deacetylases',
#   'PR_EXT SirT1',
#   'NCBITaxon_EXT yeast',
#   'PR_EXT Sir2',
#   'SO_EXT evolutionarily conserved',
#   'PR_EXT Sir2',
#   'NCBITaxon_EXT Yeast',
#   'PR_EXT Sir2',
#   'GO silencing',
#   'GO_EXT transcription',
#   'GO_SO_EXT telomeric region',
#   'GO mating',
#   'GO ribosomal',
#   'CHEBI_SO_EXT DNA',
#   'GO_SO_EXT recombination',
#   'GO expression',
#   'SO_EXT copy',
#   'PR_EXT Sir2',
#   'NCBITaxon_EXT yeast',
#   'CL_GO_EXT cells',
#   'UBERON_EXT mult',
#   'NCBITaxon organorga',
#   'NCBITaxon nematodes',
#   'PR_EXT Sir2',
#   'NCBITaxon_EXT yeast',
#   'CL_GO_EXT cells',
#   'PR_EXT Sir2',
#   'UBERON lilifesp',
#   'PR_EXT SirT1',
#   'GO regulates',
#   'GO reproductive',
#   'UBERON lifespan',
#   'UBERON chronological lifespan',
#   'NCBITaxon mammals',
#   'PR_EXT SirS',
#   'SO_EXT evolutionarily conserved',
#   'PR_EXT insulin',
#   'PR_EXT insinsulin-li',
#   'GO_EXT growth factor',
#   'PR_EXT -1',
#   'PR_EXT IGF-1',
#   'GO_EXT signaling',
#   'NCBITaxon w',
#   'NCBITaxon Caenorhabditis elegans',
#   'NCBITaxon fruit flies',
#   'NCBITaxon Drosophila',
#   'NCBITaxon mice',
#   'NCBITaxon humans',
#   'GO membrane',
#   'CHEMINF_GO_EXT bound',
#   'GO_EXT receptors',
#   'GO cytoplasmic',
#   'GO_EXT kinases',
#   'GO nuclear',
#   'GO_EXT transcription factors',
#   'GO expression',
#   'SO_EXT genes',
#   'SO_EXT conserved',
#   'GO regulatory',
#   'GO forkhead',
#   'GO_EXT transcription factoti',
#   'GO khead',
#   'CHEBI_PR_EXT proteins',
#   'PR_EXT SirT1',
#   'CHEBI_PR_EXT protein',
#   'GO deacetylation',
#   'GO_EXT transcriptional',
#   'GO nuclear',
#   'GO_EXT transcriptionnscripti',
#   'GO_EXT transcription faripti',
#   'GO cytoplasm',
#   'GO_PATO_EXT phosphorylates',
#   'PR_EXT Akt',
#   'GO_EXT kinases',
#   'GO_EXT response',
#   'PR_EXT insulin',
#   'PR_EXT IGF-1',
#   'PR_EXT insulin',
#   'PR_EXT IGF-1',
#   'GO_EXT negatively regulates',
#   'GO expression',
#   'CHEBI_EXT effe',
#   'SO_EXT genes',
#   'CHEBI_EXT food',
#   'NCBITaxon organisms',
#   'NCBITaxon C. elegaC.',
#   'NCBITaxon species',
#   'CHEBI steroid',
#   'CHEBI_GO_EXT hormones',
#   'GO regulate',
#   'NCBITaxon mice',
#   'NCBITaxon humans',
#   'PR_EXT IGF-1',
#   'GO_EXT ssignalin',
#   'GO_EXT growth',
#   'GO regulation',
#   'UBERON tissues',
#   'UBERON mammary glaamm',
#   'NCBITaxon Mammalian',
#   'PR_EXT SirT1',
#   'GO_EXT transcription factors',
#   'PR_EXT p53',
#   'PR_EXT NFNF-',
#   'PR_EXT PGC-1α',
#   'PR_EXT SirT1',
#   'CL_GO_EXT cellular',
#   'GO responses',
#   'GO_PATO_EXT inflammation',
#   'CHEBI_EXT nutrients',
#   'PR_EXT SirT1',
#   'NCBITaxon mice',
#   'UBERON peri',
#   'GO natal death',
#   'GO_EXT growth',
#   'UBERON eye',
#   'PR_EXT SirT1',
#   'NCBITaxon mice',
#   'PATO_UBERON_EXT male',
#   'PATO_UBERON_EXT female',
#   'NCBITaxon mice',
#   'PR_EXT SirT1',
#   'NCBITaxon mice',
#   'PR_EXT SirT1',
#   'PR_EXT IGF-1',
#   'GO_EXT signaling',
#   'GO m',
#   'UBERON mammary glan',
#   'UBERON organ',
#   'UBERON mammary gland',
#   'GO birth',
#   'GO reproductive',
#   'PATO_UBERON_EXT female',
#   'CHEBI_EXT estrogen',
#   'GO morphogenesis',
#   'CL epithelial',
#   'CL_GO_EXT cells',
#   'GO_RO_EXT differentiate',
#   'GO proliferate',
#   'CL adipocytes and stromal ',
#   'CL_GO_EXT cells',
#   'CHEBI_GO_PR_EXT growth',
#   'CL stromal ',
#   'CL_GO_EXT cells',
#   'PR_EXT IGF-1',
#   'PR_EXT IGF-1',
#   'UBERON liver',
#   'PR_EXT IGF-1',
#   'GO paracrine',
#   'GO morphogenesis',
#   'NCBITaxon Mice',
#   'PR_EXT IGF-1',
#   'GO_PR_EXT GH recepto',
#   'GO_EXT G',
#   'GO_PR_EXT estrogen receptor',
#   'PR_EXT  alpha',
#   'PR_EXT ERα',
#   'GO natal',
#   'GO_EXT du',
#   'GO morphogenesis',
#   'CHEBI steroid',
#   'CHEBI_GO_EXT hormhorm',
#   'PR_EXT IGF-1',
#   'UBERON ductal network',
#   'GO_RO_EXT differentiation',
#   'GO proliferation, and death of secre',
#   'GO_EXT secr',
#   'UBERON alveolar epithelium',
#   'GO pregnancy',
#   'GO morphogenesis',
#   'PR_EXT SirT1',
#   'NCBITaxon mice',
#   'PR_EXT SirT1',
#   'GO regulatory',
#   'PR_EXT estroestrogen–',
#   'GO_EXT signaling',
#   'GO mammary gland development',
#   'PR_EXT estrogen– estr',
#   'GO_EXT signaling',
#   'CHEBI estrogen',
#   'GO regulated',
#   'CL ststroma',
#   'CL_GO_EXT cell',
#   'PR_EXT IGF-1',
#   'UBERON e',
#   'CL epithelial',
#   'CL_GO_EXT cells',
#   'NCBITaxon Mice',
#   'SO_EXT construct',
#   'NCBITaxon mice',
#   'SO_EXT mutation',
#   'PR_EXT SirT1',
#   'SO_EXT geng',
#   'PR_EXT SirT1',
#   'NCBITaxon mice',
#   'GO_EXT breeding',
#   'PR_EXT SirSi',
#   'NCBITaxon mice',
#   'NCBITaxon CMV',
#   'SO_EXT transgenic',
#   'NCBITaxon mice',
#   'NCBITaxon mice',
#   'GO_SO_EXT trans',
#   'SO_EXT deletion',
#   'SO_EXT exon',
#   'PR_EXT SirT1',
#   'SO_EXT gene',
#   'PR_EXT SirT1',
#   'SO_EXT +',
#   'NCBITaxon mice',
#   'PR_EXT SirT1',
#   'NCBITaxon mice',
#   'PR_EXT SirT1',
#   'SO_EXT +',
#   'NCBITaxon mice',
#   'GO_EXT breeding',
#   'PR_EXT SirT1',
#   'PR_EXT SirT1',
#   'NCBITaxon mice',
#   'NCBITaxon mice',
#   'NCBITaxon mice',
#   'NCBITaxon Mice',
#   'NCBITaxon Animal',
#   'SO_EXT wild-type',
#   'PR_EXT SirT1',
#   'SO_EXT gene',
#   'SO_EXT priprim',
#   'SO_EXT primer',
#   'SO_EXT primer',
#   'SO_EXT primer',
#   'NCBITaxon Murine',
#   'UBERON embryonic',
#   'CL fibroblasts',
#   'UBERON embryos',
#   'UBERON embryonic',
#   'UBERON embryonic',
#   'UBERON_EXT body',
# ...
#   'GO_EXT down-regulated',
#   'GO_RO_EXT differentiaiffe',
#   'CHEBI_SO_EXT markers',
#   'CL_EXT neural stem',
#   'CL_GO_EXT cells',
#   'PR_EXT SOXB1',
#   'CL stem ',
#   'CL_GO_EXT cells',
#   'CL_EXT neural st',
#   'CL_GO_EXT cell',
#   'GO neurogenesis',
#   'PR_EXT SOX1',
#   'GO neurogenesis',
#   'GO cell cycle',
#   'NCBITaxon mice',
#   'SO_EXT null',
#   'PR_EXT Sox1',
#   'PR_EXT Sox3',
#   'NCBITaxon mice',
#   'PR_EXT Sox2',
#   'SO_EXT allele',
#   'SO_EXT deleted',
#   'CL neuronal',
#   'PR_EXT SOXB1',
#   'GO eexpresse',
#   'CL neurons',
#   'SO_EXT mutant',
#   'NCBITaxon mice',
#   'GO mitotic',
#   'CL_GO_EXT cells',
#   'PR_EXT SOX1',
#   'GO_RO_EXT differentiation',
#   'CL lens fibers',
#   'CHEBI γ-crystallins',
#   'CL VS neurons',
#   'PR_EXT SOX1',
#   'GO generation, proliferation',
#   'GO_PATO_EXT patterning',
#   'CL neuronne',
#   'PR_EXT SOX2',
#   'PR_EXT SOX3',
#   'GO expressed',
#   'PR_EXT SOX1',
#   'NCBITaxon mice',
#   'CL neuron',
#   'GO expression',
#   'PR_EXT SSox',
#   'UBERON telencephalon',
#   'CL VS neuronV',
#   'CL neurons',
#   'PR_EXT Sox1',
#   'GO expression',
#   'CL neurons',
#   'UBERON telencephalon',
#   'PR_EXT SOX1',
#   'GO mitotic',
#   'CL_GO_EXT cells',
#   'GO_EXT migration',
#   'GO neuronal migratio',
#   'GO_EXT l',
#   'GO mitotic',
#   'CL_GO_EXT cells',
#   'GO_EXT transcription factors',
#   'PR_EXT SOX1',
#   'PR_EXT SOX1',
#   'GO Histogenesis',
#   'PR_EXT Sox1',
#   'GO expression',
#   'UBERON adult',
#   'UBERON brain',
#   'NCBITaxon mice',
#   'SO_EXT allele',
#   'PR_EXT Sox1',
#   'SO_EXT insertiin',
#   'GO_EXT β-galactosidase',
#   'CHEBI_GO_EXT neo',
#   'GO_EXT βgeo',
#   'SO_EXT fusion',
#   'CHEBI_PR_EXT protein',
#   'SO in-frame',
#   'PR_EXT SOX1',
#   'SO_EXT reading frame',
#   'NCBITaxon Mice',
#   'PR_EXT Sox1β',
#   'SO_EXT null',
#   'PR_EXT SOX1',
#   'NCBITaxon mice',
#   'SO_EXT deletion',
#   'PR_EXT SOX1',
#   'SO_EXT codingcoding ',
#   'PR_EXT Sox1M1',
#   'GO_EXT β-galactosidase',
#   'CHEBI X-gal',
#   'PR_EXT Sox1',
#   'SO_EXT +',
#   'UBERON embryos',
#   'SO_EXT wild-type',
#   'SO_EXT allele',
#   'GO hybridization',
#   'PR_EXT SOX1',
#   'GO antibody',
#   'PR_EXT SOXS',
#   'GO expression',
#   'PR_EXT Sox1',
#   'UBERON brains',
#   'UBERON embryonic',
#   'GO natal',
#   'CHEBI X-gal',
#   'UBERON CNS',
#   'CHEBI X-gal',
#   'PR_EXT Sox1β',
#   'CHEBI X-gal',
#   'NCBITaxon mice',
#   'NCBITaxon animals',
#   'NCBITaxon mice',
#   'PR_EXT Sox1',
#   'SO_EXT null',
#   'SO_EXT alleles',
#   'GO_EXT ββge',
#   'PR_EXT Sox1β',
#   'SO_EXT allele',
#   'PR_EXT Sox1M1',
#   'GO express',
#   'GO_EXT β-galactosidase',
#   'CHEBI X-gal',
#   'UBERON forebrain',
#   'PR_EXT Sox1',
#   'GO expressed',
#   'UBERON ventricular zone',
#   'UBERON subvventricula',
#   'CL neurons',
#   'UBERON commiss',
#   'GO nucleus',
#   'UBERON striatal bridges',
#   'CL_GO_EXT cells',
#   'CHEBI X-gal',
#   'CL neurons',
#   'GO birth',
#   'PR_EXT Sox1βg',
#   'PR_EXT M1',
#   'SO_EXT null',
#   'SO_EXT mutmuta',
#   'CHEBI X-gal',
#   'PR_EXT VZ',
#   'PR_EXT SVZ',
#   'PR_EXT Sox1',
#   'SO_EXT +',
#   'CHEBI X-gal',
#   'CL_GO_EXT cells',
#   'UBERON striatal bridges',
#   'PR_EXT Sox1',
#   'SO_EXT null',
#   'UBERON brain',
#   'CL neurons',
#   'GO apoptosis',
#   'GO cell death',
#   'SO_EXT mutant',
#   'CHEBI X-gal',
#   'UBERON telencephalon',
#   'SO_EXT mutant',
#   'GO natal',
#   'UBERON brain',
#   'PR_EXT Sox1',
#   'SO_EXT null',
#   'CL_GO_EXT cells',
#   'UBERON brain',
#   'CL neurons',
#   'GO nucleus',
#   'GO express',
#   'PR_EXT Sox1',
#   'PR_EXT SOX1',
#   'PR_EXT SOX1',
#   'UBERON OT',
#   'GO Proliferation',
#   'GO Neurogenesis',
#   'CL Neuronal',
#   'GO_RO_EXT Differentiation',
#   'PR_EXT SOX1',
#   'PR_EXT SOX1',
#   'PR_EXT SOX2',
#   'PR_EXT SOX3',
#   'GO neurogenesis',
#   'PR_EXT SOX2',
#   'PR_EXT SOX3',
#   'GO neurogenesis',
#   'PR_EXT SOX1',
#   'GO_RO_EXT differentiation',
#   'UBERON striatum',
#   'GO_EXT βIII',
#   'PR_EXT tubulin',
#   'PR_EXT TuJ1',
#   'GO antibody',
#   'CHEBI_SO_EXT marker',
#   'CL neurons',
#   'GO_RO_EXT differentiation',
#   'GO_RO_EXT differentiation',
#   'PR_EXT Sox1',
#   'SO_EXT mutants',
#   'PR_EXT SOX1',
#   'CL neuron',
#   'GO_RO_EXT ddifferentiatio',
#   'GO_RO_EXT differentiation',
#   'CL neurons',
#   'UBERON adult',
#   'GO expression',
#   'UBERON striatal',
#   'CHEBI_SO_EXT markers',
#   'PR_EXT preproenkephalin',
#   'GO Gad65/67',
#   'UBERON embryonic',
#   'CHEBI_SO_EXT markers',
#   'PR_EXT Brn4',
#   'GO_RO_EXT differentiation',
#   'GO nucleus',
#   'UBERON striatum',
#   'PR_EXT SoxS',
#   'GO expression',
#   'CL_GO_EXT cells',
#   'UBERON neneuroepitheli',
#   'GO proliferation',
#   'CL_GO_EXT cell',
#   'UBERON telencepha',
#   'CHEBI bromo-2′-deoxyuridine',
#   'CHEBI BrdU',
#   'CHEBI_SO_EXT label',
#   'GO prolifeprolif',
#   'SO_EXT wild-type',
#   'PR_EXT Sox1',
#   'SO_EXT null',
#   'UBERON embryos',
#   'UBERON brains',
#   'CL_GO_EXT cellc',
#   'PR_EXT SVZ',
#   'GO proliferation',
#   'PR_EXT SOX1',
#   'GO proliferation',
#   'GO cell cycle',
#   'PR_EXT SOX1',
#   'GO proliferation',
#   'CL neuronal',
#   'GO_RO_EXT differentiation',
#   'GO_RO_EXT differentiation',
#   'GO migration of ',
#   'CL VS neuroVS',
#   'CL Neurons',
#   'PR_EXT SOX1',
#   'CL neurons',
#   'GO_EXT migrate',
#   'PR_EXT Sox1',
#   'SO_EXT null',
#   'UBERON OT',
#   'GO express',
#   'PR_EXT Sox1',
#   'GO_RO_EXT differentiation',
#   'CHEBI_SO_EXT markers',
#   'UBERON embryos',
#   'CHEBI BrdU',
#   'GO prolifprolife',
#   'PR_EXT Sox1',
#   'UBERON striatal',
#   'CHEBI_SO_EXT markem',
#   'GO gene expression',
#   'UBERON embryonic',
#   'UBERON_EXT stages',
#   'GO birth',
#   'CHEBI_SO_EXT Labeling',
#   'UBERON eembryoni',
#   'UBERON OT',
#   'CL neurons',
#   'NCBITaxon mouse',
#   'CL striatal neurons',
#   'GO birth',
#   'SO_EXT wild-type',
#   'UBERON embryos',
#   'CHEBI BrdU',
#   'UBERON embryos',
#   'GO birth',
#   'CL neurons',
#   'GO_EXT migrate',
#   'UBERON born',
#   'PR_EXT Sox1',
#   'SO_EXT null',
#   'UBERON embryos',
#   'CL_GO_EXT cells',
#   'CHEBI_SO_EXT lalabel',
#   'CHEBI BrdU',
#   'UBERON olfactory coract',
#   'CHEBI_SO_EXT labeled',
#   'CL_GO_EXT cells',
#   'PR_EXT Sox1',
#   'SO_EXT null',
#   'GO natan',
#   'UBERON brain',
#   'UBERON striatal',
#   'CHEBI BrdU',
#   'CHEBI_SO_EXT lalabel',
#   'CL_GO_EXT cells',
#   'CHEBI X-gal',
#   'UBERON striatum',
#   'PR_EXT SOX1',
#   'GO born',
#   'CL neurons',
#   'GO_EXT migrate',
#   'UBERON striatum',
#   'GO_PATO_EXT Patterning',
#   'PR_EXT SOX1',
#   'CL VS neurons',
#   'GO_PATO_EXT patterning',
#   'GO expexpress',
#   'GO_EXT transcription factors',
#   'GO neuronal',
#   'GO_EXT transcription facipti',
#   'PR_EXT PAX6',
#   'PR_EXT GSH2',
#   'GO expressed',
#   'UBERON pallial',
#   'GO_PATO_EXT patterning',
#   'PR_EXT GSH2',
#   'SO_EXT null',
#   'NCBITaxon mice',
#   'CL neurons',
#   'PR_EXT PAX6',
#   'PR_EXT PAX6',
#   'PR_EXT GSH2',
#   'GO_PATO_EXT patterning',
#   'SO_EXT rescues',
#   'GO antibody',
#   'UBERON embryos',
#   'PR_EXT SOX1',
#   'GO expression',
#   'PR_EXT GSH2',
#   'PR_EXT PAX6',
#   'PR_EXT PAX6',
#   'GO expressing',
#   'GO mitotic',
#   'CL_GO_EXT cells',
#   'PR_EXT S2F',
#   'PR_EXT SOX1',
#   'PR_EXT PAX6',
#   'GO mitotic',
#   'CL_GO_EXT cells',
#   'PR_EXT PAX6',
#   'PR_EXT SOX1',
#   'GO expressing',
#   'CL neurons',
#   'UBERON OT',
#   'GO antibody',
#   'SO_EXT wild-type',
#   'UBERON brain',
#   'PR_EXT PAX6',
#   'PR_EXT SOX1',
#   'GO antibodies',
#   'PR_EXT Sox1',
#   'GO expressing',
#   'CL_GO_EXT cells',
#   'PR_EXT Sox1βg',
#   'PR_EXT M1',
#   'SO_EXT null',
#   'UBERON brain',
#   'GO antibody',
#   'GO_EXT ββ-galactosidas',
#   'PR_EXT PAX6',
#   'PR_EXT SOX1',
#   'CHEBI_PR_EXT proteins',
#   'GO expressed',
#   'PR_EXT S2F',
#   'GO mitotic',
#   'CL_GO_EXT cells',
#   'GO expression',
#   'PR_EXT Pax6',
#   'GO expressing',
#   'CL neurons',
#   'GO expressing',
#   'PR_EXT Sox1',
#   'UBERON olfactory cortex',
#   'PR_EXT Sox1',
#   'SO_EXT null',
#   'NCBITaxon micm',
#   'GO mitotic',
#   'PR_EXT Pax6',
#   'GO expressing',
#   'CL_GO_EXT cells',
#   'GO_PATO_EXT localiloc',
#   'PR_EXT Pax6',
#   'GO expressing',
#   'CL neurons',
#   'PR_EXT Sox1',
#   'SO_EXT null',
#   'CL neurons',
#   'GO expressing',
#   'PR_EXT PAX6',
#   'GO_EXT βgeo',
#   'SO_EXT mmutan',
#   'PR_EXT Sox1',
#   'SO_EXT allele',
#   'UBERON pial',
#   'GO pi',
#   'CL_GO_EXT cells',
#   'GO_EXT migration',
#   'CL neurons',
#   'CHEBI X-gal',
#   'GO_EXT β-galactβ-galac',
#   'GO antibody',
#   'NCBITaxon mice',
#   'PR_EXT Sox1',
#   'SO_EXT allele',
#   'GO cytoplasmic',
#   'PR_EXT SOX1',
#   'GO expressine',
#   'GO glia',
#   'PR_EXT Sox1',
#   'SO_EXT nunu',
#   'PR_EXT RC2',
#   'GO antibody',
#   'SO_EXT wild-type',
#   'PR_EXT Pax6',
#   'GO expressing',
#   'CL neurons',
#   'PR_EXT Sox1',
#   'SO_EXT null',
#   'NCBITaxon mice',
#   'CL radial glial',
#   'GO_EXT trantranscription fa',
#   'PR_EXT MASH1',
#   'PR_EXT DLX1',
#   'PR_EXT MASH1',
#   'NCBITaxon mice',
#   'CL striatal neurons',
#   'UBERON OT',
#   'GO nucleus',
#   'PR_EXT Gsh2',
#   'SO_EXT null',
#   'NCBITaxon mice',
#   'PR_EXT DDlx',
#   'GO expression',
#   'GO expression',
#   'SO_EXT genes',
#   'PR_EXT Sox1',
#   'SO_EXT null',
#   'UBERON embryos',
#   'PR_EXT SOX1',
#   'PR_EXT SOX1',
#   'GO_PATO_EXT patternipa',
#   'PR_EXT Sox1',
#   'GO ExpressExp',
#   'PR_EXT Sox2',
#   'SO_EXT Promoter',
#   'PR_EXT SoxB1',
#   'SO_EXT genes',
#   'GO expressed',
#   'UBERON neural',
#   'GO mitotic',
#   'CL_GO_EXT cells',
#   'GO anantibo',
#   'SO_EXT genes',
#   'PR_EXT SOX2',
#   'PR_EXT SOX3',
#   'CL neurons',
#   'GO expressing',
#   'PR_EXT SOX1',
#   'PR_EXT SoxB1',
#   'SO_EXT genes',
#   'PR_EXT SoxS',
#   'CL_GO_EXT cells',
#   'PR_EXT SOX1',
#   'GO mitotmi',
#   'CL_GO_EXT cells',
#   'GO_EXT migration',
#   'NCBITaxon mmic',
#   'GO express',
#   'PR_EXT Sox1',
#   'CL neuronn',
#   'PR_EXT Sox2',
#   'GO expressed',
#   'PR_EXT Sox1',
#   'GO_EXT down-regulated',
#   'CL neurons',
#   'NCBITaxon mice',
#   'GO express',
#   'PR_EXT Sox1',
#   'PR_EXT Sox2',
#   'SO_EXT promotpr',
#   'PR_EXT Sox1',
#   'PR_EXT Sox2',
#   'GO expression',
#   'PR_EXT SVZ',
#   'UBERON telencephalic',
#   'GO antibodies',
#   'SO_EXT genes',
#   'GO nuclear',
#   'PR_EXT SOX1',
#   'PR_EXT SOX2',
#   'SO_EXT replacement',
#   'PR_EXT SOX2',
#   'SO_EXT open reading frame',
#   'PR_EXT SOX1',
#   'PR_EXT Sox2',
#   'SO_EXT allele',
#   'SO_EXT allele',
#   'PR_EXT Sox2R',
#   'GO express',
#   'PR_EXT SSox',
#   'GO_EXT βgeo',
#   'SO_EXT internal',
#   'GO ribosomal',
#   'SO_EXT  entry site',
#   'SO_EXT IRES',
#   'SO_EXT coding region',
#   'PR_EXT SOX1',
#   'PR_EXT Sox2',
#   'SO R',
#   'SO_EXT allele',
#   'SO flflank',
#   'SO_EXT LoxP sites',
#   'SO_EXT deleted',
#   'GO_SO_EXT recrecombinat',
#   'NCBITaxon mouse',
#   'SO_EXT allele',
#   'PR_EXT Sox2βgeo2',
#   'PR_EXT Sox2',
#   'CHEBI_PR_EXT βgeo',
#   'GO expresses',
#   'GO_EXT βgeo',
#   'SO_EXT gene',
#   'PR_EXT Sox2',
#   'SO_EXT promoter',
#   'PR_EXT SOX1',
#   'PR_EXT Sox2',
#   'SO_EXT +',
#   'PR_EXT Sox2',
#   'SO_EXT +',
#   'NCBITaxon mice',
#   'PR_EXT SOX1',
#   'GO expression',
#   'GO expression',
#   'PR_EXT Sox2',
#   'GO expressed',
#   'CHEBI X-gal',
#   'UBERON embryos',
#   'PR_EXT Sox2',
#   'SO_EXT alleles',
#   'PR_EXT Sox2',
#   'PR_EXT Sox2R',
#   'GO express',
#   'GO βgeo',
#   'UBERON CNS',
#   'PR_EXT SOX1',
#   'CHEBI_PR_EXT protein',
#   'PR_EXT Sox2R',
#   'SO_EXT allele',
#   'PR_EXT SOX1',
#   'GO antibody',
#   'PR_EXT SOX1',
#   'CHEBI_PR_EXT protein',
#   'PR_EXT SOX2',
#   'GO expressioe',
#   'UBERON diencephalon',
#   'UBERON sensory placodes',
#   'GO expression',
#   'SO_EXT wild-type',
#   'PR_EXT Sox1',
#   'SO_EXT alleles',
#   'GO expression',
#   'SO_EXT wild-type',
#   'SO_EXT allele',
#   'PR_EXT Sox2R',
#   'SO_EXT allele',
#   'PR_EXT SOX1',
#   'CL neurons',
#   'PR_EXT SOX2',
#   'PR_EXT SOX1',
#   'CL neurons',
#   'GO express',
#   'SO_EXT genes',
#   'NCBITaxon mice',
#   'GO expression',
#   'PR_EXT SOX1',
#   'CL_GO_EXT cells',
#   'GO expressing',
#   'PR_EXT Sox2',
#   'CHEBI_PR_EXT proteipr',
#   'SO_EXT genes',
#   'PR_EXT Sox1',
#   'GO Expression',
#   'GO expression',
#   'PR_EXT Sox1',
#   'PR_EXT Sox2',
#   'SO_EXT +',
#   'NCBITaxon mice',
#   'NCBITaxon mice',
#   'GO_EXT migration',
#   'PR_EXT Sox1',
#   'PR_EXT Sox2',
#   'CL neurons',
#   'CHEBI X-gal',
#   'PATO_UBERON_EXT Newborn',
#   'NCBITaxon mice',
#   'PR_EXT Sox2',
#   'SO_EXT +',
#   'PR_EXT Sox2',
#   'SO_EXT +',
#   'PR_EXT Sox1',
#   'SO_EXT +',
#   'SO_EXT +',
#   'PR_EXT Sox2',
#   'SO_EXT +',
#   'PR_EXT Sox1M1',
#   'SO_EXT +',
#   'PR_EXT Sox1',
#   'SO_EXT wild-type',
#   'SO_EXT alleles',
#   'PR_EXT Sox2',
#   'SO_EXT +',
#   'PR_EXT Sox1',
#   'SO_EXT +',
#   'SO_EXT +',
#   'GO expreex',
#   'PR_EXT Sox1',
#   'NCBITaxon mice',
#   'SO_EXT wild-type',
#   'PR_EXT Sox2',
#   'SO_EXT allele',
#   'PR_EXT Sox1',
#   'GO_EXT βgeo',
#   'PR_EXT Sox2',
#   'GO_EXT βgeo neurons',
#   'UBERON telencephalon',
#   'PR_EXT Sox1',
#   'SO_EXT +',
#   'PR_EXT Sox2',
#   'SO_EXT +',
#   'NCBITaxon mice',
#   'UBERON brain',
#   'PR_EXT Sox2',
#   'CL neurons',
#   'PR_EXT Sox1',
#   'UBERON tissue',
#   'CHEBI X-gal',
#   'PR_EXT Sox1',
#   'GO_EXT βgeo',
#   'PR_EXT Sox2',
#   'GO_EXT βgeo',
#   'GO antiboda',
#   'PR_EXT Sox2',
#   'GO_EXT βgeo',
#   'CL neurons',
#   'CL VS neuronal',
#   'GO expression',
#   'PR_EXT Sox1',
#   'UBERON LGE',
#   'CL neurone',
#   'GO_EXT migratimi',
#   'CL neurons',
#   'GO expressing',
#   'GO_EXT βgeo',
#   'PR_EXT Sox2',
#   'SO_EXT prpromot',
#   'PR_EXT Sox1',
#   'SO_EXT alleles',
#   'PR_EXT Sox1',
#   'GO_RO_EXT differentiation',
#   'CL VS neurons',
#   'UBERON striatal',
#   'CHEBI_SO_EXT markers',
#   'CHEBI dopamido',
#   'GO_EXT cAMP-regulated',
#   'CHEBI phosphoprot',
#   'CHEBI_PR_EXT ein',
#   'PR_EXT DARPP',
#   'GO natal',
#   'PR_EXT Sox2',
#   'SO_EXT +',
#   'NCBITaxon mice',
#   'GO expression',
#   'PR_EXT SOX1',
#   'GO neuronal',
#   'PR_EXT Sox1',
#   'GO Expression',
#   'PR_EXT SOX1',
#   'PR_EXT Sox1M1',
#   'SO_EXT +',
#   'PR_EXT Sox2',
#   'SO_EXT +',
#   'NCBITaxon mice',
#   'PR_EXT Sox1',
#   'SO_EXT +',
#   'PR_EXT SoxS',
#   'SO_EXT +',
#   'SO_EXT +',
#   'NCBITaxon mice',
#   'PR_EXT Sox2',
#   'SO_EXT +',
#   'SO_EXT wild-type',
#   'PR_EXT Sox1',
#   'SO_EXT alleles',
#   'PR_EXT Sox1M1',
#   'PR_EXT βgeo',
#   'PR_EXT Sox1',
#   'SO_EXT +',
#   'UBERON embryos',
#   'PR_EXT Sox1',
#   'SO_EXT aallel',
#   'PR_EXT SOX1',
#   'GO expressed',
#   'PR_EXT Sox2R',
#   'SO_EXT allele',
#   'GO_EXT down-regulated',
#   'CL_GO_EXT cells',
#   'GO expression',
#   'PR_EXT Sox1',
#   'SO_EXT mutant',
#   'SO_EXT allele',
#   'CHEBI_SO_EXT marks',
#   'CL neurone',
#   'PR_EXT Sox1M1',
#   'PR_EXT βgeo',
#   'CL neurons',
#   'CHEBI X-gaX',
#   'UBERON embryos',
#   'PR_EXT Sox2R',
#   'SO_EXT allele',
#   'GO expresses',
#   'GO β',
#   'CHEBI βge',
#   'GO mitotic',
#   'CL_GO_EXT cells',
#   'PR_EXT Sox2',
#   'PR_EXT βgeo',
#   'GO expression',
#   'PR_EXT Sox1',
#   'GO_EXT βgeo',
#   'CHEBI X-gal',
#   'CHEBI X-gal',
#   'UBERON braib',
#   'CHEBI X-gal',
#   'PR_EXT SOX1',
#   'GO antiboan',
#   'CHEBI X-gal',
#   'CL OT neurons',
#   'PR_EXT Sox1',
#   'SO_EXT +',
#   'NCBITaxon mice',
#   'PR_EXT Sox1',
#   'SO_EXT null',
#   'UBERON embryos',
#   'PR_EXT Sox1',
#   'PR_EXT Sox2',
#   'SO_EXT +',
#   'PR_EXT Sox1',
#   'SO_EXT null',
#   'UBERON embryos',
#   'PR_EXT Sox2R',
#   'SO_EXT allele',
#   'PR_EXT SOSO',
#   'CHEBI_PR_EXT protein',
#   'PR_EXT SOX1',
#   'CHEBI_PR_EXT proteip',
#   'NCBITaxon mice',
#   'PR_EXT SOX1',
#   'GO antibody',
#   'PR_EXT Sox1',
#   'SO_EXT +',
#   'UBERON emembry',
#   'PR_EXT SOX1',
#   'UBERON OT',
#   'CL neurons',
#   'PR_EXT Sox1βg',
#   'PR_EXT M1',
#   'SO_EXT null',
#   'UBERON embryos',
#   'PR_EXT SOX1',
#   'GO expression',
#   'UBERON embryos',
#   'PR_EXT SOX1',
#   'CHEBI_PR_EXT protein',
#   'CL neurons',
#   'NCBITaxon mice',
#   'PR_EXT Sox1',
#   'SO_EXT nulls',
#   'UBERON eyes',
#   'GO_EXT lethality',
#   'PR_EXT Sox1',
#   'SO_EXT null',
#   'NCBITaxon mice',
#   'UBERON brain',
#   'NCBITaxon mice',
#   'PR_EXT DARPP',
#   'GO antibody',
#   'PR_EXT SOSO',
#   'UBERON striatal',
#   'CHEBI_SO_EXT marker',
#   'CL OOT neuron',
#   'UBERON striatal',
#   'PR_EXT SOX1',
#   'GO expression',
#   'SO_EXT rescue',
#   'CL neuron',
#   'PR_EXT SOX1',
#   'GO mitotic',
#   'CL_GO_EXT cells',
#   'PR_EXT SSox',
#   'PR_EXT Sox2',
#   'GO Expression',
#   'CL Neurons',
#   'NCBITaxon mice',
#   'PR_EXT Sox1',
#   'SO_EXT +',
#   'SO_EXT +',
#   'PR_EXT Sox1M1',
#   'SO_EXT +',
#   'PR_EXT Sox1',
#   'SO_EXT wild-type',
#   'SO_EXT alleles',
#   'GO_EXT migration',
#   'PR_EXT Sox2',
#   'CL neurons',
#   'NCBITaxon mice',
#   'PR_EXT Sox2',
#   'SO_EXT +',
#   'SO_EXT alalle',
#   'PR_EXT Sox1',
#   'PR_EXT Sox2',
#   'CL neurons',
#   'GO_EXT migrated',
#   'PR_EXT Sox1',
#   'SO_EXT alleles',
#   'NCBITaxon mice',
#   'CHEBI X-gal',
#   'CL neurons',
#   'NCBITaxon mmic',
#   'PR_EXT Sox1M1',
#   'SO_EXT alleles',
#   'GO_EXT βgeo',
#   'GO expression',
#   'PR_EXT Sox2R',
#   'SO_EXT allele',
#   'NCBITaxon mice',
#   'CL neurons',
#   'GO_EXT migratm',
#   'PR_EXT SOX1',
#   'CL neurons',
#   'GO expression',
#   'PR_EXT Sox1',
#   'CL neneuro',
#   'GO_EXT migration',
#   'PR_EXT Sox1',
#   ...]}

# %%
fw = open('str_entcategory_text.txt','wb')
pickle.dump(str_entcategory_text, fw)
fw.close()

# %%
pre_bert = dict()
a=[]
for fileName in str_entcategory_text.keys():
    for i,j in enumerate(str_entcategory_text[fileName]):
        if i == 0:
            a = bc.encode([j]) 
        else:
            b = bc.encode([j]) 
            a = np.concatenate((a,b))
    pre_bert[fileName]=a

# %%
fw = open('pre_bert.txt','wb')
pickle.dump(pre_bert, fw)
fw.close()

# %%
label_name_doct=dict()
for filename in pre_bert.keys():
    
    final_list=[]
    for i in pre_bert[filename]:
        index_ = np.argmax(cosine_similarity([i], label_bert))
        final_list.append(detaillabel[index_])
    label_name_doct[filename] = final_list
    print(filename)

# %%
class Evaluator1(object):
    @staticmethod
    def check_match(ent_a, ent_b, doc_ids):
        ent_id = int(ent_a.ent_id[1:]) - 1
        
        #return (ent_a.category == ent_b.category and
                #max(ent_a.start_pos, ent_b.start_pos) < min(ent_a.end_pos, ent_b.end_pos))
        return (label_name_doct[doc_ids][ent_id] == doct_detail_label[doc_ids][ent_b.ent_id] and
                max(ent_a.start_pos, ent_b.start_pos) < min(ent_a.end_pos, ent_b.end_pos))

    @staticmethod
    def count_intersects(ent_list_a, ent_list_b, doc_ids):
        num_hits = 0
        ent_list_b = ent_list_b.copy()
        for ent_a in ent_list_a:
            hit_ent = None
            for ent_b in ent_list_b:
                if Evaluator1.check_match(ent_a, ent_b,doc_ids ):
                    hit_ent = ent_b
                    break
            if hit_ent is not None:
                num_hits += 1
                ent_list_b.remove(hit_ent)
        return num_hits

    @staticmethod
    def f1_score(gt_docs, pred_docs):
        num_hits = 0
        num_preds = 0
        num_gts = 0
        for doc_id in gt_docs.doc_ids:
            gt_ents = gt_docs[doc_id].ents.ents
            pred_ents = pred_docs[doc_id].ents.ents
            num_gts += len(gt_ents)
            num_preds += len(pred_ents)
            num_hits += Evaluator1.count_intersects(pred_ents, gt_ents,doc_id)
        p = num_hits / num_preds
        r = num_hits / num_gts
        f = 2 * p * r / (p + r)
        return f, p, r

# %%
f_score, precision, recall = Evaluator1.f1_score(test_docs,pred_docs)
print('f_score: ', f_score)
print('precision: ', precision)
print('recall: ', recall)

# %%
import pickle
fr = open('doct_detail_label.txt','rb')
doct_detail_label = pickle.load(fr)
doct_detail_label
